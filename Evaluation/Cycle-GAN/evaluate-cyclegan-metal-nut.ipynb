# %%
# !cp -r /kaggle/input/metal-nut-weights/* /kaggle/working

# %%
# !cp -r /kaggle/input/metal-nut/* /kaggle/working

# %% [markdown]
# # Introduction
#
# In this project, we will attempt to greate a Cycle Generative Adversarial Network (cycleGAN) in order to manipulate defective industrial parts. We will attempt to augment images data.

# %% [markdown]
# Our first step is to load the neccessary libraries we will be using for the entire process.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torch.optim import Adam
from torch.utils.data import DataLoader
import torch.utils.data as data
import random
from torchvision import transforms
from PIL import Image
from scipy.stats import ttest_ind
from sklearn.metrics import roc_auc_score
import os , itertools, cv2
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Since we are using two platforms, we will be assigning a directory to the location of the data for each platform. This will make it easier to access the data, depending the platform we will be using.
#
# The two platforms will be:
# 1. A local installation of  Jupyter Notebook - work on local codes. GPU is limited
# 2. A Google Colaboratory Notebook - Use of available resources and GPU to run the model

# %%
data_dir = 'metal_nut'
train_dir = os.path.join(data_dir,'train')
test_dir = os.path.join(data_dir,'test')

# %% [markdown]
# ## Parameters
#
# In this block, we will create global parameters which we can use at different areas of this project.

# %%
# Creating the Parameters

parameters = {
    'batch_size': 1,
    'input_size': 256,
    'resize_scale': 286,
    'crop_size': 256,
    'fliplr':True,
    
    # Model parameters
    'num_epochs': 100,
    'decay_epoch': 100,
    'ngf': 32,   # Number of generator filters
    'ndf': 64,   # Number of discriminator filters
    'num_resnet': 6, # Number of resnet blocks
    'lrG': 0.0002,    # Learning rate for generator
    'lrD': 0.0002,    # Learning rate for discriminator
    'beta1': 0.5 ,    # Beta1 for Adam optimizer
    'beta2': 0.999 ,  # Beta2 for Adam optimizer
    'lambdaA': 10 ,   # LambdaA for cycle loss
    'lambdaB': 10  ,  # LambdaB for cycle loss
}

# %% [markdown]
# ## Creating functions
#
# In the next set, we will create several functions that will be used throughout. The first function will convert our data into Numpy, which we can call at a later point.
#
# We will also set a variable so we can use a GPU for faster processing.

# %%
# Convert to Numpy 
def to_numpy(x):
    return x.data.cpu().numpy()

def load_weights(model, optimizer, filename):
    if os.path.isfile(filename):
        ckpt = torch.load(filename)
        model.load_state_dict(ckpt['model_state_dict'])
        optimizer.load_state_dict(ckpt['optimizer_state_dict'])
    else:
        print(f'No checkpoint found at {filename}')
        
def save_image(image, save_path, i):
    img = to_numpy(image[0])
    img = img.squeeze()
    img = (((img - img.min()) * 255) / (img.max() - img.min())).transpose(1, 2, 0).astype(np.uint8)
    img_path = os.path.join(save_path, f"image_{i}.jpg")
    cv2.imwrite(img_path, img)

# Use GPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Transformer
#
# Since we will be using a __transformer__ at a later stage, we will set a transformer variable and assign it procedures which transforms an image size accordingly. This transformer will also convert the image into a Tensor and Normalize it as well.

# %%
transform = transforms.Compose([
    transforms.Resize(size=parameters['input_size']),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# %% [markdown]
# Next, we will define an __ImagePool__ function

# %%
class ImagePool():
    def __init__(self, pool_size):
        self.pool_size = pool_size
        if self.pool_size > 0:
            self.num_imgs = 0
            self.images = []

    def query(self, images):
        if self.pool_size == 0:
            return images
        return_images = []
        for image in images.data:
            image = torch.unsqueeze(image, 0)
            if self.num_imgs < self.pool_size:
                self.num_imgs = self.num_imgs + 1
                self.images.append(image)
                return_images.append(image)
            else:
                p = random.uniform(0, 1)
                if p > 0.5:
                    random_id = random.randint(0, self.pool_size-1)
                    tmp = self.images[random_id].clone()
                    self.images[random_id] = image
                    return_images.append(tmp)
                else:
                    return_images.append(image)
        return_images = Variable(torch.cat(return_images, 0))
        return return_images

# %% [markdown]
# ### Creating the Dataloader
#
# In this section, we begin by creating the __dataloader__ which we will use to retrieve the data in parts.

# %%
class DatasetFromFolder(data.Dataset):
    def __init__(self, image_dir, subfolder='train', transform=None, resize_scale=None, crop_size=None, fliplr=False):
        super(DatasetFromFolder, self).__init__()
        self.input_path = os.path.join(image_dir, subfolder)
        self.image_filenames = [x for x in sorted(os.listdir(self.input_path))]
        self.transform = transform

        self.resize_scale = resize_scale
        self.crop_size = crop_size
        self.fliplr = fliplr

    def __getitem__(self, index):
        # Load Image
        img_fn = os.path.join(self.input_path, self.image_filenames[index])
        img = Image.open(img_fn).convert('RGB')

        # preprocessing
        if self.resize_scale:
            img = img.resize((self.resize_scale, self.resize_scale), Image.BILINEAR)

        if self.crop_size:
            x = random.randint(0, self.resize_scale - self.crop_size + 1)
            y = random.randint(0, self.resize_scale - self.crop_size + 1)
            img = img.crop((x, y, x + self.crop_size, y + self.crop_size))
        if self.fliplr:
            if random.random() < 0.5:
                img = img.transpose(Image.FLIP_LEFT_RIGHT)

        if self.transform is not None:
            img = self.transform(img)

        return img

    def __len__(self):
        return len(self.image_filenames)

# %% [markdown]
# ### Creating the Convolutional Block
#
# The __convolution__ block will consist of two things.
#
# 1. Initialization
#
# 2. Forward pass.

# %%
class ConvBlock(torch.nn.Module):
    def __init__(self,input_size,output_size,kernel_size=3,stride=2,padding=1,activation='relu',batch_norm=True):
        super(ConvBlock,self).__init__()
        self.conv = torch.nn.Conv2d(input_size,output_size,kernel_size,stride,padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
        self.lrelu = torch.nn.LeakyReLU(0.2,True)
        self.tanh = torch.nn.Tanh()
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.conv(x))
        else:
            out = self.conv(x)

        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### De-Convolution Function
#
# In this class we will create, we will need to bring back the convolution from the results previously processed. There will be two functions inside this class.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class DeconvBlock(torch.nn.Module):
    def __init__(self,input_size,output_size,kernel_size=3,stride=2,padding=1,output_padding=1,activation='relu',batch_norm=True):
        super(DeconvBlock,self).__init__()
        self.deconv = torch.nn.ConvTranspose2d(input_size,output_size,kernel_size,stride,padding,output_padding)
        self.batch_norm = batch_norm
        self.bn = torch.nn.InstanceNorm2d(output_size)
        self.activation = activation
        self.relu = torch.nn.ReLU(True)
    def forward(self,x):
        if self.batch_norm:
            out = self.bn(self.deconv(x))
        else:
            out = self.deconv(x)
        if self.activation == 'relu':
            return self.relu(out)
        elif self.activation == 'lrelu':
            return self.lrelu(out)
        elif self.activation == 'tanh':
            return self.tanh(out)
        elif self.activation == 'no_act':
            return out

# %% [markdown]
# ### Residual Learning Block
#
# In this secton, we will create a __residual learning__ block or __Resnet__. This class will also contain two functions.
#
# 1. Initialization
#
# 2. Forward pass

# %%
class ResnetBlock(torch.nn.Module):
    def __init__(self,num_filter,kernel_size=3,stride=1,padding=0):
        super(ResnetBlock,self).__init__()
        conv1 = torch.nn.Conv2d(num_filter,num_filter,kernel_size,stride,padding)
        conv2 = torch.nn.Conv2d(num_filter,num_filter,kernel_size,stride,padding)
        bn = torch.nn.InstanceNorm2d(num_filter)
        relu = torch.nn.ReLU(True)
        pad = torch.nn.ReflectionPad2d(1)

        self.resnet_block = torch.nn.Sequential(pad, conv1, bn, relu, pad, conv2, bn)
    def forward(self,x):
        out = self.resnet_block(x)
        return out

# %% [markdown]
# ## Creating the Generator
#
# We will now create the __Generator__. The Generator will consist of the following:
# 1. Encoder
# 2. Transformer
# 3. Decoder
#
# In addition, we will also be adding __weights__.
#
# After creating the class, we will create the actuall Generator.

# %%
class Generator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim,num_resnet):
        super(Generator,self).__init__()

        # Reflection padding
        self.pad = torch.nn.ReflectionPad2d(3)
        # Encoder
        self.conv1 = ConvBlock(input_dim,num_filter,kernel_size=7,stride=1,padding=0)
        self.conv2 = ConvBlock(num_filter,num_filter*2)
        self.conv3 = ConvBlock(num_filter*2,num_filter*4)
        # Resnet blocks
        self.resnet_blocks = []
        for i in range(num_resnet):
            self.resnet_blocks.append(ResnetBlock(num_filter*4))
        self.resnet_blocks = torch.nn.Sequential(*self.resnet_blocks)
        #Decoder
        self.deconv1 = DeconvBlock(num_filter*4,num_filter*2)
        self.deconv2 = DeconvBlock(num_filter*2,num_filter)
        self.deconv3 = ConvBlock(num_filter,output_dim,kernel_size=7,stride=1,padding=0,activation='tanh',batch_norm=False)

    def forward(self,x):
        # Encoder
        enc1 = self.conv1(self.pad(x))
        enc2 = self.conv2(enc1)
        enc3 = self.conv3(enc2)
        # Resnet blocks
        res = self.resnet_blocks(enc3)
        # Decoder
        dec1 = self.deconv1(res)
        dec2 = self.deconv2(dec1)
        out = self.deconv3(self.pad(dec2))
        return out

    def normal_weight_init(self,mean=0.0,std=0.02):
        for m in self.children():
            if isinstance(m,ConvBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
            if isinstance(m,DeconvBlock):
                torch.nn.init.normal_(m.deconv.weight,mean,std)
            if isinstance(m,ResnetBlock):
                torch.nn.init.normal_(m.conv.weight,mean,std)
                torch.nn.init.constant_(m.conv.bias,0)

# %% [markdown]
# ### Creating the Generator and Testing the Neural Network
#
# Since we will be using a Cycle GAN, which requires 2 Neural Networks competing with each other, we will create 2 Generators as its requirement. We will also test it by calling it and view the results created earlier.

# %% [markdown]
# #### Generator A

# %%
# Load Generators
G_A = Generator(3, parameters['ngf'], 3, parameters['num_resnet']).cuda() # input_dim, num_filter, output_dim, num_resnet
G_A.load_state_dict(torch.load('Generator_A.pth'))
G_A.eval()
# Out:
# Generator(
#   (pad): ReflectionPad2d((3, 3, 3, 3))
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (resnet_blocks): Sequential(
#     (0): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (deconv1): DeconvBlock(
#     (deconv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv2): DeconvBlock(
#     (deconv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv3): ConvBlock(
#     (conv): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# #### Generator B
#
# Repeating the previous step, but for Generator B.

# %%
G_B = Generator(3, parameters['ngf'], 3, parameters['num_resnet']).cuda()
G_B.load_state_dict(torch.load('Generator_B.pth'))
G_B.eval()
# Out:
# Generator(
#   (pad): ReflectionPad2d((3, 3, 3, 3))
#   (conv1): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv2): ConvBlock(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (conv3): ConvBlock(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
#   (resnet_blocks): Sequential(
#     (0): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (1): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (2): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (3): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (4): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#     (5): ResnetBlock(
#       (resnet_block): Sequential(
#         (0): ReflectionPad2d((1, 1, 1, 1))
#         (1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (3): ReLU(inplace=True)
#         (4): ReflectionPad2d((1, 1, 1, 1))
#         (5): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#         (6): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       )
#     )
#   )
#   (deconv1): DeconvBlock(
#     (deconv): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv2): DeconvBlock(
#     (deconv): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     (bn): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#   )
#   (deconv3): ConvBlock(
#     (conv): Conv2d(32, 3, kernel_size=(7, 7), stride=(1, 1))
#     (bn): InstanceNorm2d(3, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (relu): ReLU(inplace=True)
#     (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# ## Creating the Discriminator
#
# The Discriminator will consist of the following
# 1. Initialization
# 2. Forward Pass
# 3. Weights
#
# After creating the class, we will create the actuall Discriminator.

# %%
class Discriminator(torch.nn.Module):
    def __init__(self,input_dim,num_filter,output_dim):
        super(Discriminator,self).__init__()
        conv1 = ConvBlock(input_dim,num_filter,kernel_size=4,stride=2,padding=1,activation='lrelu',batch_norm=False)
        conv2 = ConvBlock(num_filter,num_filter*2,kernel_size=4,stride=2,padding=1,activation='lrelu')
        conv3 = ConvBlock(num_filter*2,num_filter*4,kernel_size=4,stride=2,padding=1,activation='lrelu')
        conv4 = ConvBlock(num_filter*4,num_filter*8,kernel_size=4,stride=1,padding=1,activation='lrelu')
        conv5 = ConvBlock(num_filter*8,output_dim,kernel_size=4,stride=1,padding=1,activation='no_act',batch_norm=False)
        self.conv_blocks = torch.nn.Sequential(conv1, conv2, conv3, conv4, conv5)
    
    def forward(self,x):
        out = self.conv_blocks(x)
        return out

    def normal_weight_init(self,mean=0.0,std=0.02):
        for m in self.children():
            if isinstance(m,ConvBlock):
                torch.nn.init.normal_(m.conv.weight.data,mean,std)

# %% [markdown]
# ### Creating the Discriminator and Testing the Neural Network
#
# Similar with the Generator, which requires 2 Neural Networks. A cycleGAN also uses 2 Discriminators.

# %% [markdown]
# #### Discriminator A

# %%
# Load Discriminators
D_A = Discriminator(3, parameters['ndf'], 1).cuda() # input_dim, num_filter, output_dim
D_A.load_state_dict(torch.load('Discriminator_A.pth'))
D_A.eval()
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# #### Discriminator B

# %%
D_B = Discriminator(3, parameters['ndf'], 1).cuda()
D_B.load_state_dict(torch.load('Discriminator_B.pth'))
D_B.eval()
# Out:
# Discriminator(
#   (conv_blocks): Sequential(
#     (0): ConvBlock(
#       (conv): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (1): ConvBlock(
#       (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (2): ConvBlock(
#       (conv): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (bn): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (3): ConvBlock(
#       (conv): Conv2d(256, 512, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#     (4): ConvBlock(
#       (conv): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#       (bn): InstanceNorm2d(1, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace=True)
#       (lrelu): LeakyReLU(negative_slope=0.2, inplace=True)
#       (tanh): Tanh()
#     )
#   )
# )

# %% [markdown]
# ## Training Block / DataLoaders
#
# In this block, we will create the actual training block we will be using to train our model.

# %%
train_data_A = DatasetFromFolder(train_dir, subfolder='good', transform=transform,resize_scale=parameters['resize_scale'], crop_size=parameters['crop_size'], fliplr=parameters['fliplr'])
train_data_loader_A = torch.utils.data.DataLoader(dataset=train_data_A,batch_size=parameters['batch_size'], shuffle=True)
train_data_B = DatasetFromFolder(train_dir, subfolder='bad', transform=transform, resize_scale=parameters['resize_scale'], crop_size=parameters['crop_size'], fliplr=parameters['fliplr'])
train_data_loader_B = torch.utils.data.DataLoader(dataset=train_data_B, batch_size=parameters['batch_size'], shuffle=True)

#Load test data
test_data_A = DatasetFromFolder(test_dir, subfolder='good', transform=transform)
test_data_loader_A = torch.utils.data.DataLoader(dataset=test_data_A, batch_size=parameters['batch_size'], shuffle=False)
test_data_B = DatasetFromFolder(test_dir, subfolder='bad', transform=transform)
test_data_loader_B = torch.utils.data.DataLoader(dataset=test_data_B, batch_size=parameters['batch_size'], shuffle=False)

# %% [markdown]
# ## Creating the Optimizer
#
# In this block, we need to create the learning optimizers. We will have one optimizer for the Generator and two optimizers for the Discriminator. The Discriminator has two optimizers as this function checks the data generated by the Generator.

# %%
G_optimizer = torch.optim.Adam(itertools.chain(G_A.parameters(), G_B.parameters()), lr=parameters['lrG'], betas=(parameters['beta1'], parameters['beta2']))
G_optimizer.load_state_dict(torch.load('Generator_optimizer.pth'))

D_A_optimizer = torch.optim.Adam(D_A.parameters(), lr=parameters['lrD'], betas=(parameters['beta1'], parameters['beta2']))
D_A_optimizer.load_state_dict(torch.load('Discriminator_A_optimizer.pth'))

D_B_optimizer = torch.optim.Adam(D_B.parameters(), lr=parameters['lrD'], betas=(parameters['beta1'], parameters['beta2']))
D_B_optimizer.load_state_dict(torch.load('Discriminator_B_optimizer.pth'))

# %% [markdown]
# ## Defining Losses
#
# In order to make sure that there is learning, we will create cycle losses, which we will pass on at a later time.

# %%
MSE_Loss = torch.nn.MSELoss().cuda()
L1_Loss = torch.nn.L1Loss().cuda()

# %%
good_save_path = 'good_generated_images'
bad_save_path = 'bad_generated_images'
os.makedirs(good_save_path, exist_ok=True)
os.makedirs(bad_save_path, exist_ok=True)

# %%
test_real_A_data = train_data_A.__getitem__(8).unsqueeze(0)
test_real_B_data = train_data_B.__getitem__(6).unsqueeze(0)
i = 0
for epoch in range(200):
    # Show result for test image
    test_real_A = test_real_A_data.cuda()
    test_fake_B = G_A(test_real_A)
    test_recon_A = G_B(test_fake_B)

    test_real_B = test_real_B_data.cuda()
    test_fake_A = G_B(test_real_B)
    test_recon_B = G_A(test_fake_A)
    (bad_one, good_one), (good_two, bad_two) = [test_fake_B, test_fake_A], [test_recon_A, test_recon_B]
    
    save_image(good_one, good_save_path, i)
    i +=1
    save_image(good_two, good_save_path, i)
    i +=1
    save_image(bad_one, bad_save_path, i)
    i +=1
    save_image(bad_two, bad_save_path, i)
    i +=1

# %%
# !zip -r metal-nut-generated-images.zip good_generated_images/* bad_generated_images/*
# Out:
#   adding: good_generated_images/image_0.jpg (deflated 1%)
#   adding: good_generated_images/image_1.jpg (deflated 1%)
#   adding: good_generated_images/image_100.jpg (deflated 1%)
#   adding: good_generated_images/image_101.jpg (deflated 1%)
#   adding: good_generated_images/image_104.jpg (deflated 1%)
#   adding: good_generated_images/image_105.jpg (deflated 1%)
#   adding: good_generated_images/image_108.jpg (deflated 1%)
#   adding: good_generated_images/image_109.jpg (deflated 1%)
#   adding: good_generated_images/image_112.jpg (deflated 1%)
#   adding: good_generated_images/image_113.jpg (deflated 1%)
#   adding: good_generated_images/image_116.jpg (deflated 1%)
#   adding: good_generated_images/image_117.jpg (deflated 1%)
#   adding: good_generated_images/image_12.jpg (deflated 1%)
#   adding: good_generated_images/image_120.jpg (deflated 1%)
#   adding: good_generated_images/image_121.jpg (deflated 1%)
#   adding: good_generated_images/image_124.jpg (deflated 1%)
#   adding: good_generated_images/image_125.jpg (deflated 1%)
#   adding: good_generated_images/image_128.jpg (deflated 1%)
#   adding: good_generated_images/image_129.jpg (deflated 1%)
#   adding: good_generated_images/image_13.jpg (deflated 1%)
#   adding: good_generated_images/image_132.jpg (deflated 1%)
#   adding: good_generated_images/image_133.jpg (deflated 1%)
#   adding: good_generated_images/image_136.jpg (deflated 1%)
#   adding: good_generated_images/image_137.jpg (deflated 1%)
#   adding: good_generated_images/image_140.jpg (deflated 1%)
#   adding: good_generated_images/image_141.jpg (deflated 1%)
#   adding: good_generated_images/image_144.jpg (deflated 1%)
#   adding: good_generated_images/image_145.jpg (deflated 1%)
#   adding: good_generated_images/image_148.jpg (deflated 1%)
#   adding: good_generated_images/image_149.jpg (deflated 1%)
#   adding: good_generated_images/image_152.jpg (deflated 1%)
#   adding: good_generated_images/image_153.jpg (deflated 1%)
#   adding: good_generated_images/image_156.jpg (deflated 1%)
#   adding: good_generated_images/image_157.jpg (deflated 1%)
#   adding: good_generated_images/image_16.jpg (deflated 1%)
#   adding: good_generated_images/image_160.jpg (deflated 1%)
#   adding: good_generated_images/image_161.jpg (deflated 1%)
#   adding: good_generated_images/image_164.jpg (deflated 1%)
#   adding: good_generated_images/image_165.jpg (deflated 1%)
#   adding: good_generated_images/image_168.jpg (deflated 1%)
#   adding: good_generated_images/image_169.jpg (deflated 1%)
#   adding: good_generated_images/image_17.jpg (deflated 1%)
#   adding: good_generated_images/image_172.jpg (deflated 1%)
#   adding: good_generated_images/image_173.jpg (deflated 1%)
#   adding: good_generated_images/image_176.jpg (deflated 1%)
#   adding: good_generated_images/image_177.jpg (deflated 1%)
#   adding: good_generated_images/image_180.jpg (deflated 1%)
#   adding: good_generated_images/image_181.jpg (deflated 1%)
#   adding: good_generated_images/image_184.jpg (deflated 1%)
#   adding: good_generated_images/image_185.jpg (deflated 1%)
#   adding: good_generated_images/image_188.jpg (deflated 1%)
#   adding: good_generated_images/image_189.jpg (deflated 1%)
#   adding: good_generated_images/image_192.jpg (deflated 1%)
#   adding: good_generated_images/image_193.jpg (deflated 1%)
#   adding: good_generated_images/image_196.jpg (deflated 1%)
#   adding: good_generated_images/image_197.jpg (deflated 1%)
#   adding: good_generated_images/image_20.jpg (deflated 1%)
#   adding: good_generated_images/image_200.jpg (deflated 1%)
#   adding: good_generated_images/image_201.jpg (deflated 1%)
#   adding: good_generated_images/image_204.jpg (deflated 1%)
#   adding: good_generated_images/image_205.jpg (deflated 1%)
#   adding: good_generated_images/image_208.jpg (deflated 1%)
#   adding: good_generated_images/image_209.jpg (deflated 1%)
#   adding: good_generated_images/image_21.jpg (deflated 1%)
#   adding: good_generated_images/image_212.jpg (deflated 1%)
#   adding: good_generated_images/image_213.jpg (deflated 1%)
#   adding: good_generated_images/image_216.jpg (deflated 1%)
#   adding: good_generated_images/image_217.jpg (deflated 1%)
#   adding: good_generated_images/image_220.jpg (deflated 1%)
#   adding: good_generated_images/image_221.jpg (deflated 1%)
#   adding: good_generated_images/image_224.jpg (deflated 1%)
#   adding: good_generated_images/image_225.jpg (deflated 1%)
#   adding: good_generated_images/image_228.jpg (deflated 1%)
#   adding: good_generated_images/image_229.jpg (deflated 1%)
#   adding: good_generated_images/image_232.jpg (deflated 1%)
#   adding: good_generated_images/image_233.jpg (deflated 1%)
#   adding: good_generated_images/image_236.jpg (deflated 1%)
#   adding: good_generated_images/image_237.jpg (deflated 1%)
#   adding: good_generated_images/image_24.jpg (deflated 1%)
#   adding: good_generated_images/image_240.jpg (deflated 1%)
#   adding: good_generated_images/image_241.jpg (deflated 1%)
#   adding: good_generated_images/image_244.jpg (deflated 1%)
#   adding: good_generated_images/image_245.jpg (deflated 1%)
#   adding: good_generated_images/image_248.jpg (deflated 1%)
#   adding: good_generated_images/image_249.jpg (deflated 1%)
#   adding: good_generated_images/image_25.jpg (deflated 1%)
#   adding: good_generated_images/image_252.jpg (deflated 1%)
#   adding: good_generated_images/image_253.jpg (deflated 1%)
#   adding: good_generated_images/image_256.jpg (deflated 1%)
#   adding: good_generated_images/image_257.jpg (deflated 1%)
#   adding: good_generated_images/image_260.jpg (deflated 1%)
#   adding: good_generated_images/image_261.jpg (deflated 1%)
#   adding: good_generated_images/image_264.jpg (deflated 1%)
#   adding: good_generated_images/image_265.jpg (deflated 1%)
#   adding: good_generated_images/image_268.jpg (deflated 1%)
#   adding: good_generated_images/image_269.jpg (deflated 1%)
#   adding: good_generated_images/image_272.jpg (deflated 1%)
#   adding: good_generated_images/image_273.jpg (deflated 1%)
#   adding: good_generated_images/image_276.jpg (deflated 1%)
#   adding: good_generated_images/image_277.jpg (deflated 1%)
#   adding: good_generated_images/image_28.jpg (deflated 1%)
#   adding: good_generated_images/image_280.jpg (deflated 1%)
#   adding: good_generated_images/image_281.jpg (deflated 1%)
#   adding: good_generated_images/image_284.jpg (deflated 1%)
#   adding: good_generated_images/image_285.jpg (deflated 1%)
#   adding: good_generated_images/image_288.jpg (deflated 1%)
#   adding: good_generated_images/image_289.jpg (deflated 1%)
#   adding: good_generated_images/image_29.jpg (deflated 1%)
#   adding: good_generated_images/image_292.jpg (deflated 1%)
#   adding: good_generated_images/image_293.jpg (deflated 1%)
#   adding: good_generated_images/image_296.jpg (deflated 1%)
#   adding: good_generated_images/image_297.jpg (deflated 1%)
#   adding: good_generated_images/image_300.jpg (deflated 1%)
#   adding: good_generated_images/image_301.jpg (deflated 1%)
#   adding: good_generated_images/image_304.jpg (deflated 1%)
#   adding: good_generated_images/image_305.jpg (deflated 1%)
#   adding: good_generated_images/image_308.jpg (deflated 1%)
#   adding: good_generated_images/image_309.jpg (deflated 1%)
#   adding: good_generated_images/image_312.jpg (deflated 1%)
#   adding: good_generated_images/image_313.jpg (deflated 1%)
#   adding: good_generated_images/image_316.jpg (deflated 1%)
#   adding: good_generated_images/image_317.jpg (deflated 1%)
#   adding: good_generated_images/image_32.jpg (deflated 1%)
#   adding: good_generated_images/image_320.jpg (deflated 1%)
#   adding: good_generated_images/image_321.jpg (deflated 1%)
#   adding: good_generated_images/image_324.jpg (deflated 1%)
#   adding: good_generated_images/image_325.jpg (deflated 1%)
#   adding: good_generated_images/image_328.jpg (deflated 1%)
#   adding: good_generated_images/image_329.jpg (deflated 1%)
#   adding: good_generated_images/image_33.jpg (deflated 1%)
#   adding: good_generated_images/image_332.jpg (deflated 1%)
#   adding: good_generated_images/image_333.jpg (deflated 1%)
#   adding: good_generated_images/image_336.jpg (deflated 1%)
#   adding: good_generated_images/image_337.jpg (deflated 1%)
#   adding: good_generated_images/image_340.jpg (deflated 1%)
#   adding: good_generated_images/image_341.jpg (deflated 1%)
#   adding: good_generated_images/image_344.jpg (deflated 1%)
#   adding: good_generated_images/image_345.jpg (deflated 1%)
#   adding: good_generated_images/image_348.jpg (deflated 1%)
#   adding: good_generated_images/image_349.jpg (deflated 1%)
#   adding: good_generated_images/image_352.jpg (deflated 1%)
#   adding: good_generated_images/image_353.jpg (deflated 1%)
#   adding: good_generated_images/image_356.jpg (deflated 1%)
#   adding: good_generated_images/image_357.jpg (deflated 1%)
#   adding: good_generated_images/image_36.jpg (deflated 1%)
#   adding: good_generated_images/image_360.jpg (deflated 1%)
#   adding: good_generated_images/image_361.jpg (deflated 1%)
#   adding: good_generated_images/image_364.jpg (deflated 1%)
#   adding: good_generated_images/image_365.jpg (deflated 1%)
#   adding: good_generated_images/image_368.jpg (deflated 1%)
#   adding: good_generated_images/image_369.jpg (deflated 1%)
#   adding: good_generated_images/image_37.jpg (deflated 1%)
#   adding: good_generated_images/image_372.jpg (deflated 1%)
#   adding: good_generated_images/image_373.jpg (deflated 1%)
#   adding: good_generated_images/image_376.jpg (deflated 1%)
#   adding: good_generated_images/image_377.jpg (deflated 1%)
#   adding: good_generated_images/image_380.jpg (deflated 1%)
#   adding: good_generated_images/image_381.jpg (deflated 1%)
#   adding: good_generated_images/image_384.jpg (deflated 1%)
#   adding: good_generated_images/image_385.jpg (deflated 1%)
#   adding: good_generated_images/image_388.jpg (deflated 1%)
#   adding: good_generated_images/image_389.jpg (deflated 1%)
#   adding: good_generated_images/image_392.jpg (deflated 1%)
#   adding: good_generated_images/image_393.jpg (deflated 1%)
#   adding: good_generated_images/image_396.jpg (deflated 1%)
#   adding: good_generated_images/image_397.jpg (deflated 1%)
#   adding: good_generated_images/image_4.jpg (deflated 1%)
#   adding: good_generated_images/image_40.jpg (deflated 1%)
#   adding: good_generated_images/image_400.jpg (deflated 1%)
#   adding: good_generated_images/image_401.jpg (deflated 1%)
#   adding: good_generated_images/image_404.jpg (deflated 1%)
#   adding: good_generated_images/image_405.jpg (deflated 1%)
#   adding: good_generated_images/image_408.jpg (deflated 1%)
#   adding: good_generated_images/image_409.jpg (deflated 1%)
#   adding: good_generated_images/image_41.jpg (deflated 1%)
#   adding: good_generated_images/image_412.jpg (deflated 1%)
#   adding: good_generated_images/image_413.jpg (deflated 1%)
#   adding: good_generated_images/image_416.jpg (deflated 1%)
#   adding: good_generated_images/image_417.jpg (deflated 1%)
#   adding: good_generated_images/image_420.jpg (deflated 1%)
#   adding: good_generated_images/image_421.jpg (deflated 1%)
#   adding: good_generated_images/image_424.jpg (deflated 1%)
#   adding: good_generated_images/image_425.jpg (deflated 1%)
#   adding: good_generated_images/image_428.jpg (deflated 1%)
#   adding: good_generated_images/image_429.jpg (deflated 1%)
#   adding: good_generated_images/image_432.jpg (deflated 1%)
#   adding: good_generated_images/image_433.jpg (deflated 1%)
#   adding: good_generated_images/image_436.jpg (deflated 1%)
#   adding: good_generated_images/image_437.jpg (deflated 1%)
#   adding: good_generated_images/image_44.jpg (deflated 1%)
#   adding: good_generated_images/image_440.jpg (deflated 1%)
#   adding: good_generated_images/image_441.jpg (deflated 1%)
#   adding: good_generated_images/image_444.jpg (deflated 1%)
#   adding: good_generated_images/image_445.jpg (deflated 1%)
#   adding: good_generated_images/image_448.jpg (deflated 1%)
#   adding: good_generated_images/image_449.jpg (deflated 1%)
#   adding: good_generated_images/image_45.jpg (deflated 1%)
#   adding: good_generated_images/image_452.jpg (deflated 1%)
#   adding: good_generated_images/image_453.jpg (deflated 1%)
#   adding: good_generated_images/image_456.jpg (deflated 1%)
#   adding: good_generated_images/image_457.jpg (deflated 1%)
#   adding: good_generated_images/image_460.jpg (deflated 1%)
#   adding: good_generated_images/image_461.jpg (deflated 1%)
#   adding: good_generated_images/image_464.jpg (deflated 1%)
#   adding: good_generated_images/image_465.jpg (deflated 1%)
#   adding: good_generated_images/image_468.jpg (deflated 1%)
#   adding: good_generated_images/image_469.jpg (deflated 1%)
#   adding: good_generated_images/image_472.jpg (deflated 1%)
#   adding: good_generated_images/image_473.jpg (deflated 1%)
#   adding: good_generated_images/image_476.jpg (deflated 1%)
#   adding: good_generated_images/image_477.jpg (deflated 1%)
#   adding: good_generated_images/image_48.jpg (deflated 1%)
#   adding: good_generated_images/image_480.jpg (deflated 1%)
#   adding: good_generated_images/image_481.jpg (deflated 1%)
#   adding: good_generated_images/image_484.jpg (deflated 1%)
#   adding: good_generated_images/image_485.jpg (deflated 1%)
#   adding: good_generated_images/image_488.jpg (deflated 1%)
#   adding: good_generated_images/image_489.jpg (deflated 1%)
#   adding: good_generated_images/image_49.jpg (deflated 1%)
#   adding: good_generated_images/image_492.jpg (deflated 1%)
#   adding: good_generated_images/image_493.jpg (deflated 1%)
#   adding: good_generated_images/image_496.jpg (deflated 1%)
#   adding: good_generated_images/image_497.jpg (deflated 1%)
#   adding: good_generated_images/image_5.jpg (deflated 1%)
#   adding: good_generated_images/image_500.jpg (deflated 1%)
#   adding: good_generated_images/image_501.jpg (deflated 1%)
#   adding: good_generated_images/image_504.jpg (deflated 1%)
#   adding: good_generated_images/image_505.jpg (deflated 1%)
#   adding: good_generated_images/image_508.jpg (deflated 1%)
#   adding: good_generated_images/image_509.jpg (deflated 1%)
#   adding: good_generated_images/image_512.jpg (deflated 1%)
#   adding: good_generated_images/image_513.jpg (deflated 1%)
#   adding: good_generated_images/image_516.jpg (deflated 1%)
#   adding: good_generated_images/image_517.jpg (deflated 1%)
#   adding: good_generated_images/image_52.jpg (deflated 1%)
#   adding: good_generated_images/image_520.jpg (deflated 1%)
#   adding: good_generated_images/image_521.jpg (deflated 1%)
#   adding: good_generated_images/image_524.jpg (deflated 1%)
#   adding: good_generated_images/image_525.jpg (deflated 1%)
#   adding: good_generated_images/image_528.jpg (deflated 1%)
#   adding: good_generated_images/image_529.jpg (deflated 1%)
#   adding: good_generated_images/image_53.jpg (deflated 1%)
#   adding: good_generated_images/image_532.jpg (deflated 1%)
#   adding: good_generated_images/image_533.jpg (deflated 1%)
#   adding: good_generated_images/image_536.jpg (deflated 1%)
#   adding: good_generated_images/image_537.jpg (deflated 1%)
#   adding: good_generated_images/image_540.jpg (deflated 1%)
#   adding: good_generated_images/image_541.jpg (deflated 1%)
#   adding: good_generated_images/image_544.jpg (deflated 1%)
#   adding: good_generated_images/image_545.jpg (deflated 1%)
#   adding: good_generated_images/image_548.jpg (deflated 1%)
#   adding: good_generated_images/image_549.jpg (deflated 1%)
#   adding: good_generated_images/image_552.jpg (deflated 1%)
#   adding: good_generated_images/image_553.jpg (deflated 1%)
#   adding: good_generated_images/image_556.jpg (deflated 1%)
#   adding: good_generated_images/image_557.jpg (deflated 1%)
#   adding: good_generated_images/image_56.jpg (deflated 1%)
#   adding: good_generated_images/image_560.jpg (deflated 1%)
#   adding: good_generated_images/image_561.jpg (deflated 1%)
#   adding: good_generated_images/image_564.jpg (deflated 1%)
#   adding: good_generated_images/image_565.jpg (deflated 1%)
#   adding: good_generated_images/image_568.jpg (deflated 1%)
#   adding: good_generated_images/image_569.jpg (deflated 1%)
#   adding: good_generated_images/image_57.jpg (deflated 1%)
#   adding: good_generated_images/image_572.jpg (deflated 1%)
#   adding: good_generated_images/image_573.jpg (deflated 1%)
#   adding: good_generated_images/image_576.jpg (deflated 1%)
#   adding: good_generated_images/image_577.jpg (deflated 1%)
#   adding: good_generated_images/image_580.jpg (deflated 1%)
#   adding: good_generated_images/image_581.jpg (deflated 1%)
#   adding: good_generated_images/image_584.jpg (deflated 1%)
#   adding: good_generated_images/image_585.jpg (deflated 1%)
#   adding: good_generated_images/image_588.jpg (deflated 1%)
#   adding: good_generated_images/image_589.jpg (deflated 1%)
#   adding: good_generated_images/image_592.jpg (deflated 1%)
#   adding: good_generated_images/image_593.jpg (deflated 1%)
#   adding: good_generated_images/image_596.jpg (deflated 1%)
#   adding: good_generated_images/image_597.jpg (deflated 1%)
#   adding: good_generated_images/image_60.jpg (deflated 1%)
#   adding: good_generated_images/image_600.jpg (deflated 1%)
#   adding: good_generated_images/image_601.jpg (deflated 1%)
#   adding: good_generated_images/image_604.jpg (deflated 1%)
#   adding: good_generated_images/image_605.jpg (deflated 1%)
#   adding: good_generated_images/image_608.jpg (deflated 1%)
#   adding: good_generated_images/image_609.jpg (deflated 1%)
#   adding: good_generated_images/image_61.jpg (deflated 1%)
#   adding: good_generated_images/image_612.jpg (deflated 1%)
#   adding: good_generated_images/image_613.jpg (deflated 1%)
#   adding: good_generated_images/image_616.jpg (deflated 1%)
#   adding: good_generated_images/image_617.jpg (deflated 1%)
#   adding: good_generated_images/image_620.jpg (deflated 1%)
#   adding: good_generated_images/image_621.jpg (deflated 1%)
#   adding: good_generated_images/image_624.jpg (deflated 1%)
#   adding: good_generated_images/image_625.jpg (deflated 1%)
#   adding: good_generated_images/image_628.jpg (deflated 1%)
#   adding: good_generated_images/image_629.jpg (deflated 1%)
#   adding: good_generated_images/image_632.jpg (deflated 1%)
#   adding: good_generated_images/image_633.jpg (deflated 1%)
#   adding: good_generated_images/image_636.jpg (deflated 1%)
#   adding: good_generated_images/image_637.jpg (deflated 1%)
#   adding: good_generated_images/image_64.jpg (deflated 1%)
#   adding: good_generated_images/image_640.jpg (deflated 1%)
#   adding: good_generated_images/image_641.jpg (deflated 1%)
#   adding: good_generated_images/image_644.jpg (deflated 1%)
#   adding: good_generated_images/image_645.jpg (deflated 1%)
#   adding: good_generated_images/image_648.jpg (deflated 1%)
#   adding: good_generated_images/image_649.jpg (deflated 1%)
#   adding: good_generated_images/image_65.jpg (deflated 1%)
#   adding: good_generated_images/image_652.jpg (deflated 1%)
#   adding: good_generated_images/image_653.jpg (deflated 1%)
#   adding: good_generated_images/image_656.jpg (deflated 1%)
#   adding: good_generated_images/image_657.jpg (deflated 1%)
#   adding: good_generated_images/image_660.jpg (deflated 1%)
#   adding: good_generated_images/image_661.jpg (deflated 1%)
#   adding: good_generated_images/image_664.jpg (deflated 1%)
#   adding: good_generated_images/image_665.jpg (deflated 1%)
#   adding: good_generated_images/image_668.jpg (deflated 1%)
#   adding: good_generated_images/image_669.jpg (deflated 1%)
#   adding: good_generated_images/image_672.jpg (deflated 1%)
#   adding: good_generated_images/image_673.jpg (deflated 1%)
#   adding: good_generated_images/image_676.jpg (deflated 1%)
#   adding: good_generated_images/image_677.jpg (deflated 1%)
#   adding: good_generated_images/image_68.jpg (deflated 1%)
#   adding: good_generated_images/image_680.jpg (deflated 1%)
#   adding: good_generated_images/image_681.jpg (deflated 1%)
#   adding: good_generated_images/image_684.jpg (deflated 1%)
#   adding: good_generated_images/image_685.jpg (deflated 1%)
#   adding: good_generated_images/image_688.jpg (deflated 1%)
#   adding: good_generated_images/image_689.jpg (deflated 1%)
#   adding: good_generated_images/image_69.jpg (deflated 1%)
#   adding: good_generated_images/image_692.jpg (deflated 1%)
#   adding: good_generated_images/image_693.jpg (deflated 1%)
#   adding: good_generated_images/image_696.jpg (deflated 1%)
#   adding: good_generated_images/image_697.jpg (deflated 1%)
#   adding: good_generated_images/image_700.jpg (deflated 1%)
#   adding: good_generated_images/image_701.jpg (deflated 1%)
#   adding: good_generated_images/image_704.jpg (deflated 1%)
#   adding: good_generated_images/image_705.jpg (deflated 1%)
#   adding: good_generated_images/image_708.jpg (deflated 1%)
#   adding: good_generated_images/image_709.jpg (deflated 1%)
#   adding: good_generated_images/image_712.jpg (deflated 1%)
#   adding: good_generated_images/image_713.jpg (deflated 1%)
#   adding: good_generated_images/image_716.jpg (deflated 1%)
#   adding: good_generated_images/image_717.jpg (deflated 1%)
#   adding: good_generated_images/image_72.jpg (deflated 1%)
#   adding: good_generated_images/image_720.jpg (deflated 1%)
#   adding: good_generated_images/image_721.jpg (deflated 1%)
#   adding: good_generated_images/image_724.jpg (deflated 1%)
#   adding: good_generated_images/image_725.jpg (deflated 1%)
#   adding: good_generated_images/image_728.jpg (deflated 1%)
#   adding: good_generated_images/image_729.jpg (deflated 1%)
#   adding: good_generated_images/image_73.jpg (deflated 1%)
#   adding: good_generated_images/image_732.jpg (deflated 1%)
#   adding: good_generated_images/image_733.jpg (deflated 1%)
#   adding: good_generated_images/image_736.jpg (deflated 1%)
#   adding: good_generated_images/image_737.jpg (deflated 1%)
#   adding: good_generated_images/image_740.jpg (deflated 1%)
#   adding: good_generated_images/image_741.jpg (deflated 1%)
#   adding: good_generated_images/image_744.jpg (deflated 1%)
#   adding: good_generated_images/image_745.jpg (deflated 1%)
#   adding: good_generated_images/image_748.jpg (deflated 1%)
#   adding: good_generated_images/image_749.jpg (deflated 1%)
#   adding: good_generated_images/image_752.jpg (deflated 1%)
#   adding: good_generated_images/image_753.jpg (deflated 1%)
#   adding: good_generated_images/image_756.jpg (deflated 1%)
#   adding: good_generated_images/image_757.jpg (deflated 1%)
#   adding: good_generated_images/image_76.jpg (deflated 1%)
#   adding: good_generated_images/image_760.jpg (deflated 1%)
#   adding: good_generated_images/image_761.jpg (deflated 1%)
#   adding: good_generated_images/image_764.jpg (deflated 1%)
#   adding: good_generated_images/image_765.jpg (deflated 1%)
#   adding: good_generated_images/image_768.jpg (deflated 1%)
#   adding: good_generated_images/image_769.jpg (deflated 1%)
#   adding: good_generated_images/image_77.jpg (deflated 1%)
#   adding: good_generated_images/image_772.jpg (deflated 1%)
#   adding: good_generated_images/image_773.jpg (deflated 1%)
#   adding: good_generated_images/image_776.jpg (deflated 1%)
#   adding: good_generated_images/image_777.jpg (deflated 1%)
#   adding: good_generated_images/image_780.jpg (deflated 1%)
#   adding: good_generated_images/image_781.jpg (deflated 1%)
#   adding: good_generated_images/image_784.jpg (deflated 1%)
#   adding: good_generated_images/image_785.jpg (deflated 1%)
#   adding: good_generated_images/image_788.jpg (deflated 1%)
#   adding: good_generated_images/image_789.jpg (deflated 1%)
#   adding: good_generated_images/image_792.jpg (deflated 1%)
#   adding: good_generated_images/image_793.jpg (deflated 1%)
#   adding: good_generated_images/image_796.jpg (deflated 1%)
#   adding: good_generated_images/image_797.jpg (deflated 1%)
#   adding: good_generated_images/image_8.jpg (deflated 1%)
#   adding: good_generated_images/image_80.jpg (deflated 1%)
#   adding: good_generated_images/image_81.jpg (deflated 1%)
#   adding: good_generated_images/image_84.jpg (deflated 1%)
#   adding: good_generated_images/image_85.jpg (deflated 1%)
#   adding: good_generated_images/image_88.jpg (deflated 1%)
#   adding: good_generated_images/image_89.jpg (deflated 1%)
#   adding: good_generated_images/image_9.jpg (deflated 1%)
#   adding: good_generated_images/image_92.jpg (deflated 1%)
#   adding: good_generated_images/image_93.jpg (deflated 1%)
#   adding: good_generated_images/image_96.jpg (deflated 1%)
#   adding: good_generated_images/image_97.jpg (deflated 1%)
#   adding: bad_generated_images/image_10.jpg (deflated 1%)
#   adding: bad_generated_images/image_102.jpg (deflated 1%)
#   adding: bad_generated_images/image_103.jpg (deflated 1%)
#   adding: bad_generated_images/image_106.jpg (deflated 1%)
#   adding: bad_generated_images/image_107.jpg (deflated 1%)
#   adding: bad_generated_images/image_11.jpg (deflated 1%)
#   adding: bad_generated_images/image_110.jpg (deflated 1%)
#   adding: bad_generated_images/image_111.jpg (deflated 1%)
#   adding: bad_generated_images/image_114.jpg (deflated 1%)
#   adding: bad_generated_images/image_115.jpg (deflated 1%)
#   adding: bad_generated_images/image_118.jpg (deflated 1%)
#   adding: bad_generated_images/image_119.jpg (deflated 1%)
#   adding: bad_generated_images/image_122.jpg (deflated 1%)
#   adding: bad_generated_images/image_123.jpg (deflated 1%)
#   adding: bad_generated_images/image_126.jpg (deflated 1%)
#   adding: bad_generated_images/image_127.jpg (deflated 1%)
#   adding: bad_generated_images/image_130.jpg (deflated 1%)
#   adding: bad_generated_images/image_131.jpg (deflated 1%)
#   adding: bad_generated_images/image_134.jpg (deflated 1%)
#   adding: bad_generated_images/image_135.jpg (deflated 1%)
#   adding: bad_generated_images/image_138.jpg (deflated 1%)
#   adding: bad_generated_images/image_139.jpg (deflated 1%)
#   adding: bad_generated_images/image_14.jpg (deflated 1%)
#   adding: bad_generated_images/image_142.jpg (deflated 1%)
#   adding: bad_generated_images/image_143.jpg (deflated 1%)
#   adding: bad_generated_images/image_146.jpg (deflated 1%)
#   adding: bad_generated_images/image_147.jpg (deflated 1%)
#   adding: bad_generated_images/image_15.jpg (deflated 1%)
#   adding: bad_generated_images/image_150.jpg (deflated 1%)
#   adding: bad_generated_images/image_151.jpg (deflated 1%)
#   adding: bad_generated_images/image_154.jpg (deflated 1%)
#   adding: bad_generated_images/image_155.jpg (deflated 1%)
#   adding: bad_generated_images/image_158.jpg (deflated 1%)
#   adding: bad_generated_images/image_159.jpg (deflated 1%)
#   adding: bad_generated_images/image_162.jpg (deflated 1%)
#   adding: bad_generated_images/image_163.jpg (deflated 1%)
#   adding: bad_generated_images/image_166.jpg (deflated 1%)
#   adding: bad_generated_images/image_167.jpg (deflated 1%)
#   adding: bad_generated_images/image_170.jpg (deflated 1%)
#   adding: bad_generated_images/image_171.jpg (deflated 1%)
#   adding: bad_generated_images/image_174.jpg (deflated 1%)
#   adding: bad_generated_images/image_175.jpg (deflated 1%)
#   adding: bad_generated_images/image_178.jpg (deflated 1%)
#   adding: bad_generated_images/image_179.jpg (deflated 1%)
#   adding: bad_generated_images/image_18.jpg (deflated 1%)
#   adding: bad_generated_images/image_182.jpg (deflated 1%)
#   adding: bad_generated_images/image_183.jpg (deflated 1%)
#   adding: bad_generated_images/image_186.jpg (deflated 1%)
#   adding: bad_generated_images/image_187.jpg (deflated 1%)
#   adding: bad_generated_images/image_19.jpg (deflated 1%)
#   adding: bad_generated_images/image_190.jpg (deflated 1%)
#   adding: bad_generated_images/image_191.jpg (deflated 1%)
#   adding: bad_generated_images/image_194.jpg (deflated 1%)
#   adding: bad_generated_images/image_195.jpg (deflated 1%)
#   adding: bad_generated_images/image_198.jpg (deflated 1%)
#   adding: bad_generated_images/image_199.jpg (deflated 1%)
#   adding: bad_generated_images/image_2.jpg (deflated 1%)
#   adding: bad_generated_images/image_202.jpg (deflated 1%)
#   adding: bad_generated_images/image_203.jpg (deflated 1%)
#   adding: bad_generated_images/image_206.jpg (deflated 1%)
#   adding: bad_generated_images/image_207.jpg (deflated 1%)
#   adding: bad_generated_images/image_210.jpg (deflated 1%)
#   adding: bad_generated_images/image_211.jpg (deflated 1%)
#   adding: bad_generated_images/image_214.jpg (deflated 1%)
#   adding: bad_generated_images/image_215.jpg (deflated 1%)
#   adding: bad_generated_images/image_218.jpg (deflated 1%)
#   adding: bad_generated_images/image_219.jpg (deflated 1%)
#   adding: bad_generated_images/image_22.jpg (deflated 1%)
#   adding: bad_generated_images/image_222.jpg (deflated 1%)
#   adding: bad_generated_images/image_223.jpg (deflated 1%)
#   adding: bad_generated_images/image_226.jpg (deflated 1%)
#   adding: bad_generated_images/image_227.jpg (deflated 1%)
#   adding: bad_generated_images/image_23.jpg (deflated 1%)
#   adding: bad_generated_images/image_230.jpg (deflated 1%)
#   adding: bad_generated_images/image_231.jpg (deflated 1%)
#   adding: bad_generated_images/image_234.jpg (deflated 1%)
#   adding: bad_generated_images/image_235.jpg (deflated 1%)
#   adding: bad_generated_images/image_238.jpg (deflated 1%)
#   adding: bad_generated_images/image_239.jpg (deflated 1%)
#   adding: bad_generated_images/image_242.jpg (deflated 1%)
#   adding: bad_generated_images/image_243.jpg (deflated 1%)
#   adding: bad_generated_images/image_246.jpg (deflated 1%)
#   adding: bad_generated_images/image_247.jpg (deflated 1%)
#   adding: bad_generated_images/image_250.jpg (deflated 1%)
#   adding: bad_generated_images/image_251.jpg (deflated 1%)
#   adding: bad_generated_images/image_254.jpg (deflated 1%)
#   adding: bad_generated_images/image_255.jpg (deflated 1%)
#   adding: bad_generated_images/image_258.jpg (deflated 1%)
#   adding: bad_generated_images/image_259.jpg (deflated 1%)
#   adding: bad_generated_images/image_26.jpg (deflated 1%)
#   adding: bad_generated_images/image_262.jpg (deflated 1%)
#   adding: bad_generated_images/image_263.jpg (deflated 1%)
#   adding: bad_generated_images/image_266.jpg (deflated 1%)
#   adding: bad_generated_images/image_267.jpg (deflated 1%)
#   adding: bad_generated_images/image_27.jpg (deflated 1%)
#   adding: bad_generated_images/image_270.jpg (deflated 1%)
#   adding: bad_generated_images/image_271.jpg (deflated 1%)
#   adding: bad_generated_images/image_274.jpg (deflated 1%)
#   adding: bad_generated_images/image_275.jpg (deflated 1%)
#   adding: bad_generated_images/image_278.jpg (deflated 1%)
#   adding: bad_generated_images/image_279.jpg (deflated 1%)
#   adding: bad_generated_images/image_282.jpg (deflated 1%)
#   adding: bad_generated_images/image_283.jpg (deflated 1%)
#   adding: bad_generated_images/image_286.jpg (deflated 1%)
#   adding: bad_generated_images/image_287.jpg (deflated 1%)
#   adding: bad_generated_images/image_290.jpg (deflated 1%)
#   adding: bad_generated_images/image_291.jpg (deflated 1%)
#   adding: bad_generated_images/image_294.jpg (deflated 1%)
#   adding: bad_generated_images/image_295.jpg (deflated 1%)
#   adding: bad_generated_images/image_298.jpg (deflated 1%)
#   adding: bad_generated_images/image_299.jpg (deflated 1%)
#   adding: bad_generated_images/image_3.jpg (deflated 1%)
#   adding: bad_generated_images/image_30.jpg (deflated 1%)
#   adding: bad_generated_images/image_302.jpg (deflated 1%)
#   adding: bad_generated_images/image_303.jpg (deflated 1%)
#   adding: bad_generated_images/image_306.jpg (deflated 1%)
#   adding: bad_generated_images/image_307.jpg (deflated 1%)
#   adding: bad_generated_images/image_31.jpg (deflated 1%)
#   adding: bad_generated_images/image_310.jpg (deflated 1%)
#   adding: bad_generated_images/image_311.jpg (deflated 1%)
#   adding: bad_generated_images/image_314.jpg (deflated 1%)
#   adding: bad_generated_images/image_315.jpg (deflated 1%)
#   adding: bad_generated_images/image_318.jpg (deflated 1%)
#   adding: bad_generated_images/image_319.jpg (deflated 1%)
#   adding: bad_generated_images/image_322.jpg (deflated 1%)
#   adding: bad_generated_images/image_323.jpg (deflated 1%)
#   adding: bad_generated_images/image_326.jpg (deflated 1%)
#   adding: bad_generated_images/image_327.jpg (deflated 1%)
#   adding: bad_generated_images/image_330.jpg (deflated 1%)
#   adding: bad_generated_images/image_331.jpg (deflated 1%)
#   adding: bad_generated_images/image_334.jpg (deflated 1%)
#   adding: bad_generated_images/image_335.jpg (deflated 1%)
#   adding: bad_generated_images/image_338.jpg (deflated 1%)
#   adding: bad_generated_images/image_339.jpg (deflated 1%)
#   adding: bad_generated_images/image_34.jpg (deflated 1%)
#   adding: bad_generated_images/image_342.jpg (deflated 1%)
#   adding: bad_generated_images/image_343.jpg (deflated 1%)
#   adding: bad_generated_images/image_346.jpg (deflated 1%)
#   adding: bad_generated_images/image_347.jpg (deflated 1%)
#   adding: bad_generated_images/image_35.jpg (deflated 1%)
#   adding: bad_generated_images/image_350.jpg (deflated 1%)
#   adding: bad_generated_images/image_351.jpg (deflated 1%)
#   adding: bad_generated_images/image_354.jpg (deflated 1%)
#   adding: bad_generated_images/image_355.jpg (deflated 1%)
#   adding: bad_generated_images/image_358.jpg (deflated 1%)
#   adding: bad_generated_images/image_359.jpg (deflated 1%)
#   adding: bad_generated_images/image_362.jpg (deflated 1%)
#   adding: bad_generated_images/image_363.jpg (deflated 1%)
#   adding: bad_generated_images/image_366.jpg (deflated 1%)
#   adding: bad_generated_images/image_367.jpg (deflated 1%)
#   adding: bad_generated_images/image_370.jpg (deflated 1%)
#   adding: bad_generated_images/image_371.jpg (deflated 1%)
#   adding: bad_generated_images/image_374.jpg (deflated 1%)
#   adding: bad_generated_images/image_375.jpg (deflated 1%)
#   adding: bad_generated_images/image_378.jpg (deflated 1%)
#   adding: bad_generated_images/image_379.jpg (deflated 1%)
#   adding: bad_generated_images/image_38.jpg (deflated 1%)
#   adding: bad_generated_images/image_382.jpg (deflated 1%)
#   adding: bad_generated_images/image_383.jpg (deflated 1%)
#   adding: bad_generated_images/image_386.jpg (deflated 1%)
#   adding: bad_generated_images/image_387.jpg (deflated 1%)
#   adding: bad_generated_images/image_39.jpg (deflated 1%)
#   adding: bad_generated_images/image_390.jpg (deflated 1%)
#   adding: bad_generated_images/image_391.jpg (deflated 1%)
#   adding: bad_generated_images/image_394.jpg (deflated 1%)
#   adding: bad_generated_images/image_395.jpg (deflated 1%)
#   adding: bad_generated_images/image_398.jpg (deflated 1%)
#   adding: bad_generated_images/image_399.jpg (deflated 1%)
#   adding: bad_generated_images/image_402.jpg (deflated 1%)
#   adding: bad_generated_images/image_403.jpg (deflated 1%)
#   adding: bad_generated_images/image_406.jpg (deflated 1%)
#   adding: bad_generated_images/image_407.jpg (deflated 1%)
#   adding: bad_generated_images/image_410.jpg (deflated 1%)
#   adding: bad_generated_images/image_411.jpg (deflated 1%)
#   adding: bad_generated_images/image_414.jpg (deflated 1%)
#   adding: bad_generated_images/image_415.jpg (deflated 1%)
#   adding: bad_generated_images/image_418.jpg (deflated 1%)
#   adding: bad_generated_images/image_419.jpg (deflated 1%)
#   adding: bad_generated_images/image_42.jpg (deflated 1%)
#   adding: bad_generated_images/image_422.jpg (deflated 1%)
#   adding: bad_generated_images/image_423.jpg (deflated 1%)
#   adding: bad_generated_images/image_426.jpg (deflated 1%)
#   adding: bad_generated_images/image_427.jpg (deflated 1%)
#   adding: bad_generated_images/image_43.jpg (deflated 1%)
#   adding: bad_generated_images/image_430.jpg (deflated 1%)
#   adding: bad_generated_images/image_431.jpg (deflated 1%)
#   adding: bad_generated_images/image_434.jpg (deflated 1%)
#   adding: bad_generated_images/image_435.jpg (deflated 1%)
#   adding: bad_generated_images/image_438.jpg (deflated 1%)
#   adding: bad_generated_images/image_439.jpg (deflated 1%)
#   adding: bad_generated_images/image_442.jpg (deflated 1%)
#   adding: bad_generated_images/image_443.jpg (deflated 1%)
#   adding: bad_generated_images/image_446.jpg (deflated 1%)
#   adding: bad_generated_images/image_447.jpg (deflated 1%)
#   adding: bad_generated_images/image_450.jpg (deflated 1%)
#   adding: bad_generated_images/image_451.jpg (deflated 1%)
#   adding: bad_generated_images/image_454.jpg (deflated 1%)
#   adding: bad_generated_images/image_455.jpg (deflated 1%)
#   adding: bad_generated_images/image_458.jpg (deflated 1%)
#   adding: bad_generated_images/image_459.jpg (deflated 1%)
#   adding: bad_generated_images/image_46.jpg (deflated 1%)
#   adding: bad_generated_images/image_462.jpg (deflated 1%)
#   adding: bad_generated_images/image_463.jpg (deflated 1%)
#   adding: bad_generated_images/image_466.jpg (deflated 1%)
#   adding: bad_generated_images/image_467.jpg (deflated 1%)
#   adding: bad_generated_images/image_47.jpg (deflated 1%)
#   adding: bad_generated_images/image_470.jpg (deflated 1%)
#   adding: bad_generated_images/image_471.jpg (deflated 1%)
#   adding: bad_generated_images/image_474.jpg (deflated 1%)
#   adding: bad_generated_images/image_475.jpg (deflated 1%)
#   adding: bad_generated_images/image_478.jpg (deflated 1%)
#   adding: bad_generated_images/image_479.jpg (deflated 1%)
#   adding: bad_generated_images/image_482.jpg (deflated 1%)
#   adding: bad_generated_images/image_483.jpg (deflated 1%)
#   adding: bad_generated_images/image_486.jpg (deflated 1%)
#   adding: bad_generated_images/image_487.jpg (deflated 1%)
#   adding: bad_generated_images/image_490.jpg (deflated 1%)
#   adding: bad_generated_images/image_491.jpg (deflated 1%)
#   adding: bad_generated_images/image_494.jpg (deflated 1%)
#   adding: bad_generated_images/image_495.jpg (deflated 1%)
#   adding: bad_generated_images/image_498.jpg (deflated 1%)
#   adding: bad_generated_images/image_499.jpg (deflated 1%)
#   adding: bad_generated_images/image_50.jpg (deflated 1%)
#   adding: bad_generated_images/image_502.jpg (deflated 1%)
#   adding: bad_generated_images/image_503.jpg (deflated 1%)
#   adding: bad_generated_images/image_506.jpg (deflated 1%)
#   adding: bad_generated_images/image_507.jpg (deflated 1%)
#   adding: bad_generated_images/image_51.jpg (deflated 1%)
#   adding: bad_generated_images/image_510.jpg (deflated 1%)
#   adding: bad_generated_images/image_511.jpg (deflated 1%)
#   adding: bad_generated_images/image_514.jpg (deflated 1%)
#   adding: bad_generated_images/image_515.jpg (deflated 1%)
#   adding: bad_generated_images/image_518.jpg (deflated 1%)
#   adding: bad_generated_images/image_519.jpg (deflated 1%)
#   adding: bad_generated_images/image_522.jpg (deflated 1%)
#   adding: bad_generated_images/image_523.jpg (deflated 1%)
#   adding: bad_generated_images/image_526.jpg (deflated 1%)
#   adding: bad_generated_images/image_527.jpg (deflated 1%)
#   adding: bad_generated_images/image_530.jpg (deflated 1%)
#   adding: bad_generated_images/image_531.jpg (deflated 1%)
#   adding: bad_generated_images/image_534.jpg (deflated 1%)
#   adding: bad_generated_images/image_535.jpg (deflated 1%)
#   adding: bad_generated_images/image_538.jpg (deflated 1%)
#   adding: bad_generated_images/image_539.jpg (deflated 1%)
#   adding: bad_generated_images/image_54.jpg (deflated 1%)
#   adding: bad_generated_images/image_542.jpg (deflated 1%)
#   adding: bad_generated_images/image_543.jpg (deflated 1%)
#   adding: bad_generated_images/image_546.jpg (deflated 1%)
#   adding: bad_generated_images/image_547.jpg (deflated 1%)
#   adding: bad_generated_images/image_55.jpg (deflated 1%)
#   adding: bad_generated_images/image_550.jpg (deflated 1%)
#   adding: bad_generated_images/image_551.jpg (deflated 1%)
#   adding: bad_generated_images/image_554.jpg (deflated 1%)
#   adding: bad_generated_images/image_555.jpg (deflated 1%)
#   adding: bad_generated_images/image_558.jpg (deflated 1%)
#   adding: bad_generated_images/image_559.jpg (deflated 1%)
#   adding: bad_generated_images/image_562.jpg (deflated 1%)
#   adding: bad_generated_images/image_563.jpg (deflated 1%)
#   adding: bad_generated_images/image_566.jpg (deflated 1%)
#   adding: bad_generated_images/image_567.jpg (deflated 1%)
#   adding: bad_generated_images/image_570.jpg (deflated 1%)
#   adding: bad_generated_images/image_571.jpg (deflated 1%)
#   adding: bad_generated_images/image_574.jpg (deflated 1%)
#   adding: bad_generated_images/image_575.jpg (deflated 1%)
#   adding: bad_generated_images/image_578.jpg (deflated 1%)
#   adding: bad_generated_images/image_579.jpg (deflated 1%)
#   adding: bad_generated_images/image_58.jpg (deflated 1%)
#   adding: bad_generated_images/image_582.jpg (deflated 1%)
#   adding: bad_generated_images/image_583.jpg (deflated 1%)
#   adding: bad_generated_images/image_586.jpg (deflated 1%)
#   adding: bad_generated_images/image_587.jpg (deflated 1%)
#   adding: bad_generated_images/image_59.jpg (deflated 1%)
#   adding: bad_generated_images/image_590.jpg (deflated 1%)
#   adding: bad_generated_images/image_591.jpg (deflated 1%)
#   adding: bad_generated_images/image_594.jpg (deflated 1%)
#   adding: bad_generated_images/image_595.jpg (deflated 1%)
#   adding: bad_generated_images/image_598.jpg (deflated 1%)
#   adding: bad_generated_images/image_599.jpg (deflated 1%)
#   adding: bad_generated_images/image_6.jpg (deflated 1%)
#   adding: bad_generated_images/image_602.jpg (deflated 1%)
#   adding: bad_generated_images/image_603.jpg (deflated 1%)
#   adding: bad_generated_images/image_606.jpg (deflated 1%)
#   adding: bad_generated_images/image_607.jpg (deflated 1%)
#   adding: bad_generated_images/image_610.jpg (deflated 1%)
#   adding: bad_generated_images/image_611.jpg (deflated 1%)
#   adding: bad_generated_images/image_614.jpg (deflated 1%)
#   adding: bad_generated_images/image_615.jpg (deflated 1%)
#   adding: bad_generated_images/image_618.jpg (deflated 1%)
#   adding: bad_generated_images/image_619.jpg (deflated 1%)
#   adding: bad_generated_images/image_62.jpg (deflated 1%)
#   adding: bad_generated_images/image_622.jpg (deflated 1%)
#   adding: bad_generated_images/image_623.jpg (deflated 1%)
#   adding: bad_generated_images/image_626.jpg (deflated 1%)
#   adding: bad_generated_images/image_627.jpg (deflated 1%)
#   adding: bad_generated_images/image_63.jpg (deflated 1%)
#   adding: bad_generated_images/image_630.jpg (deflated 1%)
#   adding: bad_generated_images/image_631.jpg (deflated 1%)
#   adding: bad_generated_images/image_634.jpg (deflated 1%)
#   adding: bad_generated_images/image_635.jpg (deflated 1%)
#   adding: bad_generated_images/image_638.jpg (deflated 1%)
#   adding: bad_generated_images/image_639.jpg (deflated 1%)
#   adding: bad_generated_images/image_642.jpg (deflated 1%)
#   adding: bad_generated_images/image_643.jpg (deflated 1%)
#   adding: bad_generated_images/image_646.jpg (deflated 1%)
#   adding: bad_generated_images/image_647.jpg (deflated 1%)
#   adding: bad_generated_images/image_650.jpg (deflated 1%)
#   adding: bad_generated_images/image_651.jpg (deflated 1%)
#   adding: bad_generated_images/image_654.jpg (deflated 1%)
#   adding: bad_generated_images/image_655.jpg (deflated 1%)
#   adding: bad_generated_images/image_658.jpg (deflated 1%)
#   adding: bad_generated_images/image_659.jpg (deflated 1%)
#   adding: bad_generated_images/image_66.jpg (deflated 1%)
#   adding: bad_generated_images/image_662.jpg (deflated 1%)
#   adding: bad_generated_images/image_663.jpg (deflated 1%)
#   adding: bad_generated_images/image_666.jpg (deflated 1%)
#   adding: bad_generated_images/image_667.jpg (deflated 1%)
#   adding: bad_generated_images/image_67.jpg (deflated 1%)
#   adding: bad_generated_images/image_670.jpg (deflated 1%)
#   adding: bad_generated_images/image_671.jpg (deflated 1%)
#   adding: bad_generated_images/image_674.jpg (deflated 1%)
#   adding: bad_generated_images/image_675.jpg (deflated 1%)
#   adding: bad_generated_images/image_678.jpg (deflated 1%)
#   adding: bad_generated_images/image_679.jpg (deflated 1%)
#   adding: bad_generated_images/image_682.jpg (deflated 1%)
#   adding: bad_generated_images/image_683.jpg (deflated 1%)
#   adding: bad_generated_images/image_686.jpg (deflated 1%)
#   adding: bad_generated_images/image_687.jpg (deflated 1%)
#   adding: bad_generated_images/image_690.jpg (deflated 1%)
#   adding: bad_generated_images/image_691.jpg (deflated 1%)
#   adding: bad_generated_images/image_694.jpg (deflated 1%)
#   adding: bad_generated_images/image_695.jpg (deflated 1%)
#   adding: bad_generated_images/image_698.jpg (deflated 1%)
#   adding: bad_generated_images/image_699.jpg (deflated 1%)
#   adding: bad_generated_images/image_7.jpg (deflated 1%)
#   adding: bad_generated_images/image_70.jpg (deflated 1%)
#   adding: bad_generated_images/image_702.jpg (deflated 1%)
#   adding: bad_generated_images/image_703.jpg (deflated 1%)
#   adding: bad_generated_images/image_706.jpg (deflated 1%)
#   adding: bad_generated_images/image_707.jpg (deflated 1%)
#   adding: bad_generated_images/image_71.jpg (deflated 1%)
#   adding: bad_generated_images/image_710.jpg (deflated 1%)
#   adding: bad_generated_images/image_711.jpg (deflated 1%)
#   adding: bad_generated_images/image_714.jpg (deflated 1%)
#   adding: bad_generated_images/image_715.jpg (deflated 1%)
#   adding: bad_generated_images/image_718.jpg (deflated 1%)
#   adding: bad_generated_images/image_719.jpg (deflated 1%)
#   adding: bad_generated_images/image_722.jpg (deflated 1%)
#   adding: bad_generated_images/image_723.jpg (deflated 1%)
#   adding: bad_generated_images/image_726.jpg (deflated 1%)
#   adding: bad_generated_images/image_727.jpg (deflated 1%)
#   adding: bad_generated_images/image_730.jpg (deflated 1%)
#   adding: bad_generated_images/image_731.jpg (deflated 1%)
#   adding: bad_generated_images/image_734.jpg (deflated 1%)
#   adding: bad_generated_images/image_735.jpg (deflated 1%)
#   adding: bad_generated_images/image_738.jpg (deflated 1%)
#   adding: bad_generated_images/image_739.jpg (deflated 1%)
#   adding: bad_generated_images/image_74.jpg (deflated 1%)
#   adding: bad_generated_images/image_742.jpg (deflated 1%)
#   adding: bad_generated_images/image_743.jpg (deflated 1%)
#   adding: bad_generated_images/image_746.jpg (deflated 1%)
#   adding: bad_generated_images/image_747.jpg (deflated 1%)
#   adding: bad_generated_images/image_75.jpg (deflated 1%)
#   adding: bad_generated_images/image_750.jpg (deflated 1%)
#   adding: bad_generated_images/image_751.jpg (deflated 1%)
#   adding: bad_generated_images/image_754.jpg (deflated 1%)
#   adding: bad_generated_images/image_755.jpg (deflated 1%)
#   adding: bad_generated_images/image_758.jpg (deflated 1%)
#   adding: bad_generated_images/image_759.jpg (deflated 1%)
#   adding: bad_generated_images/image_762.jpg (deflated 1%)
#   adding: bad_generated_images/image_763.jpg (deflated 1%)
#   adding: bad_generated_images/image_766.jpg (deflated 1%)
#   adding: bad_generated_images/image_767.jpg (deflated 1%)
#   adding: bad_generated_images/image_770.jpg (deflated 1%)
#   adding: bad_generated_images/image_771.jpg (deflated 1%)
#   adding: bad_generated_images/image_774.jpg (deflated 1%)
#   adding: bad_generated_images/image_775.jpg (deflated 1%)
#   adding: bad_generated_images/image_778.jpg (deflated 1%)
#   adding: bad_generated_images/image_779.jpg (deflated 1%)
#   adding: bad_generated_images/image_78.jpg (deflated 1%)
#   adding: bad_generated_images/image_782.jpg (deflated 1%)
#   adding: bad_generated_images/image_783.jpg (deflated 1%)
#   adding: bad_generated_images/image_786.jpg (deflated 1%)
#   adding: bad_generated_images/image_787.jpg (deflated 1%)
#   adding: bad_generated_images/image_79.jpg (deflated 1%)
#   adding: bad_generated_images/image_790.jpg (deflated 1%)
#   adding: bad_generated_images/image_791.jpg (deflated 1%)
#   adding: bad_generated_images/image_794.jpg (deflated 1%)
#   adding: bad_generated_images/image_795.jpg (deflated 1%)
#   adding: bad_generated_images/image_798.jpg (deflated 1%)
#   adding: bad_generated_images/image_799.jpg (deflated 1%)
#   adding: bad_generated_images/image_82.jpg (deflated 1%)
#   adding: bad_generated_images/image_83.jpg (deflated 1%)
#   adding: bad_generated_images/image_86.jpg (deflated 1%)
#   adding: bad_generated_images/image_87.jpg (deflated 1%)
#   adding: bad_generated_images/image_90.jpg (deflated 1%)
#   adding: bad_generated_images/image_91.jpg (deflated 1%)
#   adding: bad_generated_images/image_94.jpg (deflated 1%)
#   adding: bad_generated_images/image_95.jpg (deflated 1%)
#   adding: bad_generated_images/image_98.jpg (deflated 1%)
#   adding: bad_generated_images/image_99.jpg (deflated 1%)

# %%
# !cp -r /kaggle/working/good_generated_images/* /kaggle/working/metal_nut/train/good

# %%
# !cp -r /kaggle/working/good_generated_images/* /kaggle/working/metal_nut/test/good

# %%
# !cp -r /kaggle/working/bad_generated_images/* /kaggle/working/metal_nut/train/bad

# %%
# !cp -r /kaggle/working/bad_generated_images/* /kaggle/working/metal_nut/test/bad

# %%
data_dir = 'metal_nut'
train_dir = os.path.join(data_dir,'train')
test_dir = os.path.join(data_dir,'test')

# %%
class ImageDataset(data.Dataset):
    def __init__(self, data_dir, transform=None):
        super(ImageDataset, self).__init__()
        self.data_dir = data_dir
        self.transform = transform
        self.data = []
        self.targets = []

        # Iterate over the data directory and load images
        for root, dirs, files in os.walk(data_dir):
            for file in files:
                image_path = os.path.join(root, file)
                image = Image.open(image_path)
                self.data.append(image)

                # Determine the class label based on the directory name
                class_label = os.path.basename(root)
                if class_label == "good":
                    self.targets.append(1)  # Assign class 1 for "good"
                elif class_label == "bad":
                    self.targets.append(0)  # Assign class 0 for "bad"

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        image = self.data[index]
        target = self.targets[index]

        if self.transform:
            image = self.transform(image)

        return image, target

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(32 * 16 * 16, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.model(x)

# %%
transform = transforms.Compose([
    transforms.RandomRotation(50),  # Rotate randomly between -50 and 50 degrees
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),  # Random scale and crop to 256x256
    transforms.RandomHorizontalFlip(),  # Flip horizontally with a 50% chance
    transforms.ToTensor(),
])

# Create data loaders
train_dataset = ImageDataset(train_dir, transform=transform)
test_dataset = ImageDataset(test_dir, transform=transform)

# Define data loaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Set device for training
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Instantiate the CNN model
model = CNN().to(device)


# Define loss function and optimizer
criterion = nn.BCELoss()
optimizer = Adam(model.parameters(), lr=0.002)

# %%
# Training loop
num_epochs = 500
model.train()

for epoch in range(num_epochs):
    for images, targets in train_loader:
        # Move data to device
        images = images.to(device)
        targets = targets.unsqueeze(1).to(device)
        
        # Convert targets to float
        targets = targets.float()

        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, targets)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print training loss
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/500], Loss: 0.6917
# Epoch [1/500], Loss: 0.6686
# Epoch [1/500], Loss: 0.7537
# Epoch [1/500], Loss: 0.7342
# Epoch [1/500], Loss: 0.6914
# Epoch [1/500], Loss: 0.6925
# Epoch [1/500], Loss: 0.6919
# Epoch [1/500], Loss: 0.6897
# Epoch [1/500], Loss: 0.6902
# Epoch [1/500], Loss: 0.6906
# Epoch [1/500], Loss: 0.6868
# Epoch [1/500], Loss: 0.6801
# Epoch [1/500], Loss: 0.6873
# Epoch [1/500], Loss: 0.6915
# Epoch [1/500], Loss: 0.6887
# Epoch [1/500], Loss: 0.6816
# Epoch [1/500], Loss: 0.6708
# Epoch [1/500], Loss: 0.6700
# Epoch [1/500], Loss: 0.6854
# Epoch [1/500], Loss: 0.6668
# Epoch [1/500], Loss: 0.6878
# Epoch [1/500], Loss: 0.6619
# Epoch [1/500], Loss: 0.6450
# Epoch [1/500], Loss: 0.7219
# Epoch [1/500], Loss: 0.7382
# Epoch [1/500], Loss: 0.6450
# Epoch [1/500], Loss: 0.7066
# Epoch [1/500], Loss: 0.6885
# Epoch [1/500], Loss: 0.6197
# Epoch [1/500], Loss: 0.6861
# Epoch [1/500], Loss: 0.6355
# Epoch [1/500], Loss: 0.6962
# Epoch [1/500], Loss: 0.6523
# Epoch [2/500], Loss: 0.6861
# Epoch [2/500], Loss: 0.6862
# Epoch [2/500], Loss: 0.6756
# Epoch [2/500], Loss: 0.5802
# Epoch [2/500], Loss: 0.5937
# Epoch [2/500], Loss: 0.7163
# Epoch [2/500], Loss: 0.6176
# Epoch [2/500], Loss: 0.7274
# Epoch [2/500], Loss: 0.6618
# Epoch [2/500], Loss: 0.6084
# Epoch [2/500], Loss: 0.7009
# Epoch [2/500], Loss: 0.7215
# Epoch [2/500], Loss: 0.5484
# Epoch [2/500], Loss: 0.7816
# Epoch [2/500], Loss: 0.7007
# Epoch [2/500], Loss: 0.6977
# Epoch [2/500], Loss: 0.7446
# Epoch [2/500], Loss: 0.6168
# Epoch [2/500], Loss: 0.7733
# Epoch [2/500], Loss: 0.6630
# Epoch [2/500], Loss: 0.7090
# Epoch [2/500], Loss: 0.7361
# Epoch [2/500], Loss: 0.7031
# Epoch [2/500], Loss: 0.6536
# Epoch [2/500], Loss: 0.6780
# Epoch [2/500], Loss: 0.6787
# Epoch [2/500], Loss: 0.6418
# Epoch [2/500], Loss: 0.6979
# Epoch [2/500], Loss: 0.6858
# Epoch [2/500], Loss: 0.6801
# Epoch [2/500], Loss: 0.6461
# Epoch [2/500], Loss: 0.6801
# Epoch [2/500], Loss: 0.6341
# Epoch [3/500], Loss: 0.6920
# Epoch [3/500], Loss: 0.6719
# Epoch [3/500], Loss: 0.6776
# Epoch [3/500], Loss: 0.6948
# Epoch [3/500], Loss: 0.6663
# Epoch [3/500], Loss: 0.6322
# Epoch [3/500], Loss: 0.6626
# Epoch [3/500], Loss: 0.6772
# Epoch [3/500], Loss: 0.5915
# Epoch [3/500], Loss: 0.6436
# Epoch [3/500], Loss: 0.7434
# Epoch [3/500], Loss: 0.5747
# Epoch [3/500], Loss: 0.6212
# Epoch [3/500], Loss: 0.7664
# Epoch [3/500], Loss: 0.6438
# Epoch [3/500], Loss: 0.7411
# Epoch [3/500], Loss: 0.6616
# Epoch [3/500], Loss: 0.7015
# Epoch [3/500], Loss: 0.6668
# Epoch [3/500], Loss: 0.6635
# Epoch [3/500], Loss: 0.6923
# Epoch [3/500], Loss: 0.6919
# Epoch [3/500], Loss: 0.6859
# Epoch [3/500], Loss: 0.6703
# Epoch [3/500], Loss: 0.6683
# Epoch [3/500], Loss: 0.6374
# Epoch [3/500], Loss: 0.6853
# Epoch [3/500], Loss: 0.6856
# Epoch [3/500], Loss: 0.6858
# Epoch [3/500], Loss: 0.6961
# Epoch [3/500], Loss: 0.6758
# Epoch [3/500], Loss: 0.7389
# Epoch [3/500], Loss: 0.6517
# Epoch [4/500], Loss: 0.6552
# Epoch [4/500], Loss: 0.6653
# Epoch [4/500], Loss: 0.6757
# Epoch [4/500], Loss: 0.6648
# Epoch [4/500], Loss: 0.6645
# Epoch [4/500], Loss: 0.6868
# Epoch [4/500], Loss: 0.7334
# Epoch [4/500], Loss: 0.6413
# Epoch [4/500], Loss: 0.6755
# Epoch [4/500], Loss: 0.6755
# Epoch [4/500], Loss: 0.6755
# Epoch [4/500], Loss: 0.6638
# Epoch [4/500], Loss: 0.6636
# Epoch [4/500], Loss: 0.6634
# Epoch [4/500], Loss: 0.6384
# Epoch [4/500], Loss: 0.6498
# Epoch [4/500], Loss: 0.6758
# Epoch [4/500], Loss: 0.6902
# Epoch [4/500], Loss: 0.6474
# Epoch [4/500], Loss: 0.6169
# Epoch [4/500], Loss: 0.6616
# Epoch [4/500], Loss: 0.7114
# Epoch [4/500], Loss: 0.6617
# Epoch [4/500], Loss: 0.6960
# Epoch [4/500], Loss: 0.6787
# Epoch [4/500], Loss: 0.6949
# Epoch [4/500], Loss: 0.6294
# Epoch [4/500], Loss: 0.7565
# Epoch [4/500], Loss: 0.6915
# Epoch [4/500], Loss: 0.7038
# Epoch [4/500], Loss: 0.6627
# Epoch [4/500], Loss: 0.6995
# Epoch [4/500], Loss: 0.5898
# Epoch [5/500], Loss: 0.6756
# Epoch [5/500], Loss: 0.6756
# Epoch [5/500], Loss: 0.6756
# Epoch [5/500], Loss: 0.6333
# Epoch [5/500], Loss: 0.6541
# Epoch [5/500], Loss: 0.6424
# Epoch [5/500], Loss: 0.6640
# Epoch [5/500], Loss: 0.6635
# Epoch [5/500], Loss: 0.6505
# Epoch [5/500], Loss: 0.7150
# Epoch [5/500], Loss: 0.7026
# Epoch [5/500], Loss: 0.7163
# Epoch [5/500], Loss: 0.6624
# Epoch [5/500], Loss: 0.6625
# Epoch [5/500], Loss: 0.7150
# Epoch [5/500], Loss: 0.6628
# Epoch [5/500], Loss: 0.6503
# Epoch [5/500], Loss: 0.6755
# Epoch [5/500], Loss: 0.6381
# Epoch [5/500], Loss: 0.6629
# Epoch [5/500], Loss: 0.6627
# Epoch [5/500], Loss: 0.6626
# Epoch [5/500], Loss: 0.6624
# Epoch [5/500], Loss: 0.7030
# Epoch [5/500], Loss: 0.6895
# Epoch [5/500], Loss: 0.7030
# Epoch [5/500], Loss: 0.6757
# Epoch [5/500], Loss: 0.6626
# Epoch [5/500], Loss: 0.6885
# Epoch [5/500], Loss: 0.6248
# Epoch [5/500], Loss: 0.6756
# Epoch [5/500], Loss: 0.7522
# Epoch [5/500], Loss: 0.5806
# Epoch [6/500], Loss: 0.6505
# Epoch [6/500], Loss: 0.6500
# Epoch [6/500], Loss: 0.6888
# Epoch [6/500], Loss: 0.6891
# Epoch [6/500], Loss: 0.6758
# Epoch [6/500], Loss: 0.7029
# Epoch [6/500], Loss: 0.6221
# Epoch [6/500], Loss: 0.7030
# Epoch [6/500], Loss: 0.6623
# Epoch [6/500], Loss: 0.6216
# Epoch [6/500], Loss: 0.6621
# Epoch [6/500], Loss: 0.7044
# Epoch [6/500], Loss: 0.6761
# Epoch [6/500], Loss: 0.6904
# Epoch [6/500], Loss: 0.7325
# Epoch [6/500], Loss: 0.7031
# Epoch [6/500], Loss: 0.7017
# Epoch [6/500], Loss: 0.6631
# Epoch [6/500], Loss: 0.6636
# Epoch [6/500], Loss: 0.5956
# Epoch [6/500], Loss: 0.6984
# Epoch [6/500], Loss: 0.6526
# Epoch [6/500], Loss: 0.6409
# Epoch [6/500], Loss: 0.7226
# Epoch [6/500], Loss: 0.7107
# Epoch [6/500], Loss: 0.6986
# Epoch [6/500], Loss: 0.6979
# Epoch [6/500], Loss: 0.6864
# Epoch [6/500], Loss: 0.6652
# Epoch [6/500], Loss: 0.6758
# Epoch [6/500], Loss: 0.6153
# Epoch [6/500], Loss: 0.6247
# Epoch [6/500], Loss: 0.7074
# Epoch [7/500], Loss: 0.6756
# Epoch [7/500], Loss: 0.6756
# Epoch [7/500], Loss: 0.6643
# Epoch [7/500], Loss: 0.6298
# Epoch [7/500], Loss: 0.7111
# Epoch [7/500], Loss: 0.6512
# Epoch [7/500], Loss: 0.6381
# Epoch [7/500], Loss: 0.6756
# Epoch [7/500], Loss: 0.6624
# Epoch [7/500], Loss: 0.6344
# Epoch [7/500], Loss: 0.6329
# Epoch [7/500], Loss: 0.7074
# Epoch [7/500], Loss: 0.6144
# Epoch [7/500], Loss: 0.7273
# Epoch [7/500], Loss: 0.6783
# Epoch [7/500], Loss: 0.7623
# Epoch [7/500], Loss: 0.6940
# Epoch [7/500], Loss: 0.6460
# Epoch [7/500], Loss: 0.7370
# Epoch [7/500], Loss: 0.6904
# Epoch [7/500], Loss: 0.6758
# Epoch [7/500], Loss: 0.6756
# Epoch [7/500], Loss: 0.6391
# Epoch [7/500], Loss: 0.6755
# Epoch [7/500], Loss: 0.6983
# Epoch [7/500], Loss: 0.6535
# Epoch [7/500], Loss: 0.6756
# Epoch [7/500], Loss: 0.7075
# Epoch [7/500], Loss: 0.6448
# Epoch [7/500], Loss: 0.6758
# Epoch [7/500], Loss: 0.6758
# Epoch [7/500], Loss: 0.6658
# Epoch [7/500], Loss: 0.6523
# Epoch [8/500], Loss: 0.6554
# Epoch [8/500], Loss: 0.6966
# Epoch [8/500], Loss: 0.6968
# Epoch [8/500], Loss: 0.6863
# Epoch [8/500], Loss: 0.6545
# Epoch [8/500], Loss: 0.6970
# Epoch [8/500], Loss: 0.6434
# Epoch [8/500], Loss: 0.6538
# Epoch [8/500], Loss: 0.7090
# Epoch [8/500], Loss: 0.6305
# Epoch [8/500], Loss: 0.6986
# Epoch [8/500], Loss: 0.6638
# Epoch [8/500], Loss: 0.6755
# Epoch [8/500], Loss: 0.6755
# Epoch [8/500], Loss: 0.6387
# Epoch [8/500], Loss: 0.7133
# Epoch [8/500], Loss: 0.7137
# Epoch [8/500], Loss: 0.6251
# Epoch [8/500], Loss: 0.6501
# Epoch [8/500], Loss: 0.7145
# Epoch [8/500], Loss: 0.6626
# Epoch [8/500], Loss: 0.7408
# Epoch [8/500], Loss: 0.6245
# Epoch [8/500], Loss: 0.6628
# Epoch [8/500], Loss: 0.7138
# Epoch [8/500], Loss: 0.6629
# Epoch [8/500], Loss: 0.6505
# Epoch [8/500], Loss: 0.6505
# Epoch [8/500], Loss: 0.6377
# Epoch [8/500], Loss: 0.6756
# Epoch [8/500], Loss: 0.6625
# Epoch [8/500], Loss: 0.6489
# Epoch [8/500], Loss: 0.8640
# Epoch [9/500], Loss: 0.7283
# Epoch [9/500], Loss: 0.7002
# Epoch [9/500], Loss: 0.6870
# Epoch [9/500], Loss: 0.6973
# Epoch [9/500], Loss: 0.6962
# Epoch [9/500], Loss: 0.6666
# Epoch [9/500], Loss: 0.6674
# Epoch [9/500], Loss: 0.6680
# Epoch [9/500], Loss: 0.6938
# Epoch [9/500], Loss: 0.6772
# Epoch [9/500], Loss: 0.6536
# Epoch [9/500], Loss: 0.6539
# Epoch [9/500], Loss: 0.6853
# Epoch [9/500], Loss: 0.6695
# Epoch [9/500], Loss: 0.6614
# Epoch [9/500], Loss: 0.6609
# Epoch [9/500], Loss: 0.6937
# Epoch [9/500], Loss: 0.6769
# Epoch [9/500], Loss: 0.6421
# Epoch [9/500], Loss: 0.6765
# Epoch [9/500], Loss: 0.6578
# Epoch [9/500], Loss: 0.7049
# Epoch [9/500], Loss: 0.6760
# Epoch [9/500], Loss: 0.6556
# Epoch [9/500], Loss: 0.6444
# Epoch [9/500], Loss: 0.6756
# Epoch [9/500], Loss: 0.7094
# Epoch [9/500], Loss: 0.6755
# Epoch [9/500], Loss: 0.6519
# Epoch [9/500], Loss: 0.6513
# Epoch [9/500], Loss: 0.6255
# Epoch [9/500], Loss: 0.7019
# Epoch [9/500], Loss: 0.7164
# Epoch [10/500], Loss: 0.6486
# Epoch [10/500], Loss: 0.6344
# Epoch [10/500], Loss: 0.7472
# Epoch [10/500], Loss: 0.6336
# Epoch [10/500], Loss: 0.6762
# Epoch [10/500], Loss: 0.7338
# Epoch [10/500], Loss: 0.7044
# Epoch [10/500], Loss: 0.6209
# Epoch [10/500], Loss: 0.6895
# Epoch [10/500], Loss: 0.6892
# Epoch [10/500], Loss: 0.6493
# Epoch [10/500], Loss: 0.6756
# Epoch [10/500], Loss: 0.6238
# Epoch [10/500], Loss: 0.6365
# Epoch [10/500], Loss: 0.7156
# Epoch [10/500], Loss: 0.6491
# Epoch [10/500], Loss: 0.6758
# Epoch [10/500], Loss: 0.6893
# Epoch [10/500], Loss: 0.6218
# Epoch [10/500], Loss: 0.6484
# Epoch [10/500], Loss: 0.6620
# Epoch [10/500], Loss: 0.6619
# Epoch [10/500], Loss: 0.7202
# Epoch [10/500], Loss: 0.6179
# Epoch [10/500], Loss: 0.6320
# Epoch [10/500], Loss: 0.6921
# Epoch [10/500], Loss: 0.7390
# Epoch [10/500], Loss: 0.6922
# Epoch [10/500], Loss: 0.6467
# Epoch [10/500], Loss: 0.6766
# Epoch [10/500], Loss: 0.7057
# Epoch [10/500], Loss: 0.7190
# Epoch [10/500], Loss: 0.7170
# Epoch [11/500], Loss: 0.6496
# Epoch [11/500], Loss: 0.7006
# Epoch [11/500], Loss: 0.6994
# Epoch [11/500], Loss: 0.6412
# Epoch [11/500], Loss: 0.6977
# Epoch [11/500], Loss: 0.6329
# Epoch [11/500], Loss: 0.6967
# Epoch [11/500], Loss: 0.6758
# Epoch [11/500], Loss: 0.6353
# Epoch [11/500], Loss: 0.6961
# Epoch [11/500], Loss: 0.7263
# Epoch [11/500], Loss: 0.6760
# Epoch [11/500], Loss: 0.6955
# Epoch [11/500], Loss: 0.7047
# Epoch [11/500], Loss: 0.6208
# Epoch [11/500], Loss: 0.6578
# Epoch [11/500], Loss: 0.6949
# Epoch [11/500], Loss: 0.6949
# Epoch [11/500], Loss: 0.7228
# Epoch [11/500], Loss: 0.6490
# Epoch [11/500], Loss: 0.6764
# Epoch [11/500], Loss: 0.6491
# Epoch [11/500], Loss: 0.6395
# Epoch [11/500], Loss: 0.6762
# Epoch [11/500], Loss: 0.6760
# Epoch [11/500], Loss: 0.6759
# Epoch [11/500], Loss: 0.6453
# Epoch [11/500], Loss: 0.6652
# Epoch [11/500], Loss: 0.6647
# Epoch [11/500], Loss: 0.6755
# Epoch [11/500], Loss: 0.6871
# Epoch [11/500], Loss: 0.6516
# Epoch [11/500], Loss: 0.6467
# Epoch [12/500], Loss: 0.6628
# Epoch [12/500], Loss: 0.6625
# Epoch [12/500], Loss: 0.6484
# Epoch [12/500], Loss: 0.6049
# Epoch [12/500], Loss: 0.7219
# Epoch [12/500], Loss: 0.6461
# Epoch [12/500], Loss: 0.6776
# Epoch [12/500], Loss: 0.6452
# Epoch [12/500], Loss: 0.7628
# Epoch [12/500], Loss: 0.5613
# Epoch [12/500], Loss: 0.6959
# Epoch [12/500], Loss: 0.6618
# Epoch [12/500], Loss: 0.7484
# Epoch [12/500], Loss: 0.6447
# Epoch [12/500], Loss: 0.6616
# Epoch [12/500], Loss: 0.6288
# Epoch [12/500], Loss: 0.6779
# Epoch [12/500], Loss: 0.7263
# Epoch [12/500], Loss: 0.6144
# Epoch [12/500], Loss: 0.7083
# Epoch [12/500], Loss: 0.6312
# Epoch [12/500], Loss: 0.6617
# Epoch [12/500], Loss: 0.6915
# Epoch [12/500], Loss: 0.6911
# Epoch [12/500], Loss: 0.7336
# Epoch [12/500], Loss: 0.6484
# Epoch [12/500], Loss: 0.6891
# Epoch [12/500], Loss: 0.6886
# Epoch [12/500], Loss: 0.7130
# Epoch [12/500], Loss: 0.7233
# Epoch [12/500], Loss: 0.6981
# Epoch [12/500], Loss: 0.6222
# Epoch [12/500], Loss: 0.5965
# Epoch [13/500], Loss: 0.6758
# Epoch [13/500], Loss: 0.6448
# Epoch [13/500], Loss: 0.6757
# Epoch [13/500], Loss: 0.7074
# Epoch [13/500], Loss: 0.6651
# Epoch [13/500], Loss: 0.7075
# Epoch [13/500], Loss: 0.7074
# Epoch [13/500], Loss: 0.7279
# Epoch [13/500], Loss: 0.7063
# Epoch [13/500], Loss: 0.6171
# Epoch [13/500], Loss: 0.6663
# Epoch [13/500], Loss: 0.7051
# Epoch [13/500], Loss: 0.6282
# Epoch [13/500], Loss: 0.6761
# Epoch [13/500], Loss: 0.6370
# Epoch [13/500], Loss: 0.6560
# Epoch [13/500], Loss: 0.7271
# Epoch [13/500], Loss: 0.6654
# Epoch [13/500], Loss: 0.6652
# Epoch [13/500], Loss: 0.6329
# Epoch [13/500], Loss: 0.6975
# Epoch [13/500], Loss: 0.6643
# Epoch [13/500], Loss: 0.6755
# Epoch [13/500], Loss: 0.6286
# Epoch [13/500], Loss: 0.6997
# Epoch [13/500], Loss: 0.6631
# Epoch [13/500], Loss: 0.6629
# Epoch [13/500], Loss: 0.6627
# Epoch [13/500], Loss: 0.6624
# Epoch [13/500], Loss: 0.6759
# Epoch [13/500], Loss: 0.6760
# Epoch [13/500], Loss: 0.6902
# Epoch [13/500], Loss: 0.5671
# Epoch [14/500], Loss: 0.6912
# Epoch [14/500], Loss: 0.5708
# Epoch [14/500], Loss: 0.7093
# Epoch [14/500], Loss: 0.6287
# Epoch [14/500], Loss: 0.7469
# Epoch [14/500], Loss: 0.6618
# Epoch [14/500], Loss: 0.6790
# Epoch [14/500], Loss: 0.6273
# Epoch [14/500], Loss: 0.5924
# Epoch [14/500], Loss: 0.6264
# Epoch [14/500], Loss: 0.6073
# Epoch [14/500], Loss: 0.8337
# Epoch [14/500], Loss: 0.6999
# Epoch [14/500], Loss: 0.7168
# Epoch [14/500], Loss: 0.5745
# Epoch [14/500], Loss: 0.6618
# Epoch [14/500], Loss: 0.6955
# Epoch [14/500], Loss: 0.7112
# Epoch [14/500], Loss: 0.6616
# Epoch [14/500], Loss: 0.7696
# Epoch [14/500], Loss: 0.6327
# Epoch [14/500], Loss: 0.6620
# Epoch [14/500], Loss: 0.6892
# Epoch [14/500], Loss: 0.7014
# Epoch [14/500], Loss: 0.6879
# Epoch [14/500], Loss: 0.6399
# Epoch [14/500], Loss: 0.6985
# Epoch [14/500], Loss: 0.6867
# Epoch [14/500], Loss: 0.6540
# Epoch [14/500], Loss: 0.6546
# Epoch [14/500], Loss: 0.7174
# Epoch [14/500], Loss: 0.6452
# Epoch [14/500], Loss: 0.7601
# Epoch [15/500], Loss: 0.6564
# Epoch [15/500], Loss: 0.6761
# Epoch [15/500], Loss: 0.6762
# Epoch [15/500], Loss: 0.6485
# Epoch [15/500], Loss: 0.6763
# Epoch [15/500], Loss: 0.6301
# Epoch [15/500], Loss: 0.6575
# Epoch [15/500], Loss: 0.6761
# Epoch [15/500], Loss: 0.6467
# Epoch [15/500], Loss: 0.6658
# Epoch [15/500], Loss: 0.7171
# Epoch [15/500], Loss: 0.7177
# Epoch [15/500], Loss: 0.6757
# Epoch [15/500], Loss: 0.6439
# Epoch [15/500], Loss: 0.6971
# Epoch [15/500], Loss: 0.6972
# Epoch [15/500], Loss: 0.6540
# Epoch [15/500], Loss: 0.6974
# Epoch [15/500], Loss: 0.6865
# Epoch [15/500], Loss: 0.6538
# Epoch [15/500], Loss: 0.6755
# Epoch [15/500], Loss: 0.6645
# Epoch [15/500], Loss: 0.6866
# Epoch [15/500], Loss: 0.6979
# Epoch [15/500], Loss: 0.7538
# Epoch [15/500], Loss: 0.6756
# Epoch [15/500], Loss: 0.7077
# Epoch [15/500], Loss: 0.6652
# Epoch [15/500], Loss: 0.6656
# Epoch [15/500], Loss: 0.6053
# Epoch [15/500], Loss: 0.6656
# Epoch [15/500], Loss: 0.6654
# Epoch [15/500], Loss: 0.5952
# Epoch [16/500], Loss: 0.6537
# Epoch [16/500], Loss: 0.6527
# Epoch [16/500], Loss: 0.6993
# Epoch [16/500], Loss: 0.6631
# Epoch [16/500], Loss: 0.6119
# Epoch [16/500], Loss: 0.6757
# Epoch [16/500], Loss: 0.7038
# Epoch [16/500], Loss: 0.5620
# Epoch [16/500], Loss: 0.7068
# Epoch [16/500], Loss: 0.6927
# Epoch [16/500], Loss: 0.6456
# Epoch [16/500], Loss: 0.6287
# Epoch [16/500], Loss: 0.7123
# Epoch [16/500], Loss: 0.6444
# Epoch [16/500], Loss: 0.6617
# Epoch [16/500], Loss: 0.6794
# Epoch [16/500], Loss: 0.6618
# Epoch [16/500], Loss: 0.6797
# Epoch [16/500], Loss: 0.5913
# Epoch [16/500], Loss: 0.6798
# Epoch [16/500], Loss: 0.7879
# Epoch [16/500], Loss: 0.8184
# Epoch [16/500], Loss: 0.6776
# Epoch [16/500], Loss: 0.6920
# Epoch [16/500], Loss: 0.6902
# Epoch [16/500], Loss: 0.7150
# Epoch [16/500], Loss: 0.6271
# Epoch [16/500], Loss: 0.6523
# Epoch [16/500], Loss: 0.6977
# Epoch [16/500], Loss: 0.6542
# Epoch [16/500], Loss: 0.6860
# Epoch [16/500], Loss: 0.6756
# Epoch [16/500], Loss: 0.7051
# Epoch [17/500], Loss: 0.6472
# Epoch [17/500], Loss: 0.6853
# Epoch [17/500], Loss: 0.6575
# Epoch [17/500], Loss: 0.6759
# Epoch [17/500], Loss: 0.6940
# Epoch [17/500], Loss: 0.6848
# Epoch [17/500], Loss: 0.7023
# Epoch [17/500], Loss: 0.6508
# Epoch [17/500], Loss: 0.7186
# Epoch [17/500], Loss: 0.7260
# Epoch [17/500], Loss: 0.6520
# Epoch [17/500], Loss: 0.6752
# Epoch [17/500], Loss: 0.6735
# Epoch [17/500], Loss: 0.6588
# Epoch [17/500], Loss: 0.6978
# Epoch [17/500], Loss: 0.6472
# Epoch [17/500], Loss: 0.6452
# Epoch [17/500], Loss: 0.6566
# Epoch [17/500], Loss: 0.6558
# Epoch [17/500], Loss: 0.6696
# Epoch [17/500], Loss: 0.6690
# Epoch [17/500], Loss: 0.6547
# Epoch [17/500], Loss: 0.7173
# Epoch [17/500], Loss: 0.6627
# Epoch [17/500], Loss: 0.6755
# Epoch [17/500], Loss: 0.6689
# Epoch [17/500], Loss: 0.6472
# Epoch [17/500], Loss: 0.6478
# Epoch [17/500], Loss: 0.6277
# Epoch [17/500], Loss: 0.6498
# Epoch [17/500], Loss: 0.5952
# Epoch [17/500], Loss: 0.6459
# Epoch [17/500], Loss: 0.6231
# Epoch [18/500], Loss: 0.6048
# Epoch [18/500], Loss: 0.5733
# Epoch [18/500], Loss: 0.6208
# Epoch [18/500], Loss: 0.5133
# Epoch [18/500], Loss: 0.4269
# Epoch [18/500], Loss: 0.5445
# Epoch [18/500], Loss: 0.4453
# Epoch [18/500], Loss: 0.4054
# Epoch [18/500], Loss: 0.8188
# Epoch [18/500], Loss: 0.4234
# Epoch [18/500], Loss: 0.5310
# Epoch [18/500], Loss: 0.3978
# Epoch [18/500], Loss: 0.5294
# Epoch [18/500], Loss: 0.6253
# Epoch [18/500], Loss: 0.4984
# Epoch [18/500], Loss: 0.5962
# Epoch [18/500], Loss: 0.3276
# Epoch [18/500], Loss: 0.5056
# Epoch [18/500], Loss: 0.5132
# Epoch [18/500], Loss: 0.4935
# Epoch [18/500], Loss: 0.4303
# Epoch [18/500], Loss: 0.4597
# Epoch [18/500], Loss: 0.4989
# Epoch [18/500], Loss: 0.4383
# Epoch [18/500], Loss: 0.4782
# Epoch [18/500], Loss: 0.3870
# Epoch [18/500], Loss: 0.5027
# Epoch [18/500], Loss: 0.4611
# Epoch [18/500], Loss: 0.4370
# Epoch [18/500], Loss: 0.4043
# Epoch [18/500], Loss: 0.5040
# Epoch [18/500], Loss: 0.3254
# Epoch [18/500], Loss: 0.1131
# Epoch [19/500], Loss: 0.6671
# Epoch [19/500], Loss: 0.5695
# Epoch [19/500], Loss: 0.4567
# Epoch [19/500], Loss: 0.3293
# Epoch [19/500], Loss: 0.3920
# Epoch [19/500], Loss: 0.7174
# Epoch [19/500], Loss: 0.4963
# Epoch [19/500], Loss: 0.5244
# Epoch [19/500], Loss: 0.3558
# Epoch [19/500], Loss: 0.4460
# Epoch [19/500], Loss: 0.3821
# Epoch [19/500], Loss: 0.4745
# Epoch [19/500], Loss: 0.5426
# Epoch [19/500], Loss: 0.3695
# Epoch [19/500], Loss: 0.3812
# Epoch [19/500], Loss: 0.3593
# Epoch [19/500], Loss: 0.5261
# Epoch [19/500], Loss: 0.3273
# Epoch [19/500], Loss: 0.5096
# Epoch [19/500], Loss: 0.5501
# Epoch [19/500], Loss: 0.4166
# Epoch [19/500], Loss: 0.4267
# Epoch [19/500], Loss: 0.5624
# Epoch [19/500], Loss: 0.5141
# Epoch [19/500], Loss: 0.3864
# Epoch [19/500], Loss: 0.2611
# Epoch [19/500], Loss: 0.3696
# Epoch [19/500], Loss: 0.6422
# Epoch [19/500], Loss: 0.6128
# Epoch [19/500], Loss: 0.4119
# Epoch [19/500], Loss: 0.3603
# Epoch [19/500], Loss: 0.3980
# Epoch [19/500], Loss: 0.3353
# Epoch [20/500], Loss: 0.3544
# Epoch [20/500], Loss: 0.4629
# Epoch [20/500], Loss: 0.6105
# Epoch [20/500], Loss: 0.5072
# Epoch [20/500], Loss: 0.4600
# Epoch [20/500], Loss: 0.4430
# Epoch [20/500], Loss: 0.4789
# Epoch [20/500], Loss: 0.4792
# Epoch [20/500], Loss: 0.4243
# Epoch [20/500], Loss: 0.3656
# Epoch [20/500], Loss: 0.4588
# Epoch [20/500], Loss: 0.4030
# Epoch [20/500], Loss: 0.3753
# Epoch [20/500], Loss: 0.3749
# Epoch [20/500], Loss: 0.3090
# Epoch [20/500], Loss: 0.3431
# Epoch [20/500], Loss: 0.3701
# Epoch [20/500], Loss: 0.3629
# Epoch [20/500], Loss: 0.5559
# Epoch [20/500], Loss: 0.4144
# Epoch [20/500], Loss: 0.4309
# Epoch [20/500], Loss: 0.4076
# Epoch [20/500], Loss: 0.4639
# Epoch [20/500], Loss: 0.5494
# Epoch [20/500], Loss: 0.4353
# Epoch [20/500], Loss: 0.3391
# Epoch [20/500], Loss: 0.3799
# Epoch [20/500], Loss: 0.3713
# Epoch [20/500], Loss: 0.5952
# Epoch [20/500], Loss: 0.5593
# Epoch [20/500], Loss: 0.3543
# Epoch [20/500], Loss: 0.3187
# Epoch [20/500], Loss: 0.3288
# Epoch [21/500], Loss: 0.4261
# Epoch [21/500], Loss: 0.3828
# Epoch [21/500], Loss: 0.6205
# Epoch [21/500], Loss: 0.7468
# Epoch [21/500], Loss: 0.4039
# Epoch [21/500], Loss: 0.4476
# Epoch [21/500], Loss: 0.3912
# Epoch [21/500], Loss: 0.4700
# Epoch [21/500], Loss: 0.4946
# Epoch [21/500], Loss: 0.3362
# Epoch [21/500], Loss: 0.4474
# Epoch [21/500], Loss: 0.4315
# Epoch [21/500], Loss: 0.7263
# Epoch [21/500], Loss: 0.4109
# Epoch [21/500], Loss: 0.4127
# Epoch [21/500], Loss: 0.3950
# Epoch [21/500], Loss: 0.4536
# Epoch [21/500], Loss: 0.2944
# Epoch [21/500], Loss: 0.5410
# Epoch [21/500], Loss: 0.3542
# Epoch [21/500], Loss: 0.4339
# Epoch [21/500], Loss: 0.4331
# Epoch [21/500], Loss: 0.4652
# Epoch [21/500], Loss: 0.4060
# Epoch [21/500], Loss: 0.3508
# Epoch [21/500], Loss: 0.3551
# Epoch [21/500], Loss: 0.4143
# Epoch [21/500], Loss: 0.3552
# Epoch [21/500], Loss: 0.4390
# Epoch [21/500], Loss: 0.5268
# Epoch [21/500], Loss: 0.4930
# Epoch [21/500], Loss: 0.5610
# Epoch [21/500], Loss: 0.4217
# Epoch [22/500], Loss: 0.5383
# Epoch [22/500], Loss: 0.3990
# Epoch [22/500], Loss: 0.5207
# Epoch [22/500], Loss: 0.4448
# Epoch [22/500], Loss: 0.4298
# Epoch [22/500], Loss: 0.3128
# Epoch [22/500], Loss: 0.3666
# Epoch [22/500], Loss: 0.3536
# Epoch [22/500], Loss: 0.4569
# Epoch [22/500], Loss: 0.3205
# Epoch [22/500], Loss: 0.4397
# Epoch [22/500], Loss: 0.4895
# Epoch [22/500], Loss: 0.5640
# Epoch [22/500], Loss: 0.3820
# Epoch [22/500], Loss: 0.4627
# Epoch [22/500], Loss: 0.2677
# Epoch [22/500], Loss: 0.3611
# Epoch [22/500], Loss: 0.3593
# Epoch [22/500], Loss: 0.3122
# Epoch [22/500], Loss: 0.2776
# Epoch [22/500], Loss: 0.4150
# Epoch [22/500], Loss: 0.3012
# Epoch [22/500], Loss: 0.3262
# Epoch [22/500], Loss: 0.2599
# Epoch [22/500], Loss: 0.2405
# Epoch [22/500], Loss: 0.6369
# Epoch [22/500], Loss: 0.3932
# Epoch [22/500], Loss: 0.3514
# Epoch [22/500], Loss: 0.3120
# Epoch [22/500], Loss: 0.3083
# Epoch [22/500], Loss: 0.3264
# Epoch [22/500], Loss: 0.3342
# Epoch [22/500], Loss: 0.2440
# Epoch [23/500], Loss: 0.4777
# Epoch [23/500], Loss: 0.2304
# Epoch [23/500], Loss: 0.1146
# Epoch [23/500], Loss: 0.1100
# Epoch [23/500], Loss: 0.2475
# Epoch [23/500], Loss: 0.1512
# Epoch [23/500], Loss: 0.2560
# Epoch [23/500], Loss: 0.2133
# Epoch [23/500], Loss: 0.6345
# Epoch [23/500], Loss: 0.2540
# Epoch [23/500], Loss: 0.1851
# Epoch [23/500], Loss: 0.0870
# Epoch [23/500], Loss: 0.0911
# Epoch [23/500], Loss: 0.0818
# Epoch [23/500], Loss: 0.0968
# Epoch [23/500], Loss: 0.2471
# Epoch [23/500], Loss: 0.0933
# Epoch [23/500], Loss: 0.0322
# Epoch [23/500], Loss: 0.1225
# Epoch [23/500], Loss: 0.0573
# Epoch [23/500], Loss: 0.0501
# Epoch [23/500], Loss: 0.2063
# Epoch [23/500], Loss: 0.1688
# Epoch [23/500], Loss: 0.1902
# Epoch [23/500], Loss: 0.2906
# Epoch [23/500], Loss: 0.0770
# Epoch [23/500], Loss: 0.0430
# Epoch [23/500], Loss: 0.0375
# Epoch [23/500], Loss: 0.0300
# Epoch [23/500], Loss: 0.0089
# Epoch [23/500], Loss: 0.5028
# Epoch [23/500], Loss: 0.0758
# Epoch [23/500], Loss: 0.0085
# Epoch [24/500], Loss: 0.0061
# Epoch [24/500], Loss: 0.0570
# Epoch [24/500], Loss: 0.1349
# Epoch [24/500], Loss: 0.1217
# Epoch [24/500], Loss: 0.1586
# Epoch [24/500], Loss: 0.1437
# Epoch [24/500], Loss: 0.0915
# Epoch [24/500], Loss: 0.0922
# Epoch [24/500], Loss: 0.0271
# Epoch [24/500], Loss: 0.0242
# Epoch [24/500], Loss: 0.0086
# Epoch [24/500], Loss: 0.0976
# Epoch [24/500], Loss: 0.1319
# Epoch [24/500], Loss: 0.0148
# Epoch [24/500], Loss: 0.1909
# Epoch [24/500], Loss: 0.0155
# Epoch [24/500], Loss: 0.1477
# Epoch [24/500], Loss: 0.3098
# Epoch [24/500], Loss: 0.1375
# Epoch [24/500], Loss: 0.1898
# Epoch [24/500], Loss: 0.1266
# Epoch [24/500], Loss: 0.6463
# Epoch [24/500], Loss: 0.0191
# Epoch [24/500], Loss: 0.0388
# Epoch [24/500], Loss: 0.0827
# Epoch [24/500], Loss: 0.1062
# Epoch [24/500], Loss: 0.2216
# Epoch [24/500], Loss: 0.0835
# Epoch [24/500], Loss: 0.0139
# Epoch [24/500], Loss: 0.0118
# Epoch [24/500], Loss: 0.1344
# Epoch [24/500], Loss: 0.0254
# Epoch [24/500], Loss: 0.2912
# Epoch [25/500], Loss: 0.0170
# Epoch [25/500], Loss: 0.0102
# Epoch [25/500], Loss: 0.0294
# Epoch [25/500], Loss: 0.2834
# Epoch [25/500], Loss: 0.0621
# Epoch [25/500], Loss: 0.2110
# Epoch [25/500], Loss: 0.0404
# Epoch [25/500], Loss: 0.1405
# Epoch [25/500], Loss: 0.1117
# Epoch [25/500], Loss: 0.0173
# Epoch [25/500], Loss: 0.2036
# Epoch [25/500], Loss: 0.2084
# Epoch [25/500], Loss: 0.0149
# Epoch [25/500], Loss: 0.0931
# Epoch [25/500], Loss: 0.0266
# Epoch [25/500], Loss: 0.0248
# Epoch [25/500], Loss: 0.0458
# Epoch [25/500], Loss: 0.0900
# Epoch [25/500], Loss: 0.2590
# Epoch [25/500], Loss: 0.0971
# Epoch [25/500], Loss: 0.0812
# Epoch [25/500], Loss: 0.1157
# Epoch [25/500], Loss: 0.0213
# Epoch [25/500], Loss: 0.0442
# Epoch [25/500], Loss: 0.1979
# Epoch [25/500], Loss: 0.0183
# Epoch [25/500], Loss: 0.0133
# Epoch [25/500], Loss: 0.1132
# Epoch [25/500], Loss: 0.0203
# Epoch [25/500], Loss: 0.0114
# Epoch [25/500], Loss: 0.0215
# Epoch [25/500], Loss: 0.0081
# Epoch [25/500], Loss: 0.0112
# Epoch [26/500], Loss: 0.0054
# Epoch [26/500], Loss: 0.0072
# Epoch [26/500], Loss: 0.0035
# Epoch [26/500], Loss: 0.0469
# Epoch [26/500], Loss: 0.1980
# Epoch [26/500], Loss: 0.0040
# Epoch [26/500], Loss: 0.1552
# Epoch [26/500], Loss: 0.0117
# Epoch [26/500], Loss: 0.0175
# Epoch [26/500], Loss: 0.0150
# Epoch [26/500], Loss: 0.0196
# Epoch [26/500], Loss: 0.1787
# Epoch [26/500], Loss: 0.0175
# Epoch [26/500], Loss: 0.0306
# Epoch [26/500], Loss: 0.0232
# Epoch [26/500], Loss: 0.0288
# Epoch [26/500], Loss: 0.0865
# Epoch [26/500], Loss: 0.0208
# Epoch [26/500], Loss: 0.1058
# Epoch [26/500], Loss: 0.1058
# Epoch [26/500], Loss: 0.0249
# Epoch [26/500], Loss: 0.0900
# Epoch [26/500], Loss: 0.0136
# Epoch [26/500], Loss: 0.0185
# Epoch [26/500], Loss: 0.0187
# Epoch [26/500], Loss: 0.0115
# Epoch [26/500], Loss: 0.0090
# Epoch [26/500], Loss: 0.1341
# Epoch [26/500], Loss: 0.1138
# Epoch [26/500], Loss: 0.0089
# Epoch [26/500], Loss: 0.0091
# Epoch [26/500], Loss: 0.0141
# Epoch [26/500], Loss: 0.0112
# Epoch [27/500], Loss: 0.0058
# Epoch [27/500], Loss: 0.0086
# Epoch [27/500], Loss: 0.0057
# Epoch [27/500], Loss: 0.2490
# Epoch [27/500], Loss: 0.1403
# Epoch [27/500], Loss: 0.0064
# Epoch [27/500], Loss: 0.0084
# Epoch [27/500], Loss: 0.0105
# Epoch [27/500], Loss: 0.0131
# Epoch [27/500], Loss: 0.0912
# Epoch [27/500], Loss: 0.1020
# Epoch [27/500], Loss: 0.0215
# Epoch [27/500], Loss: 0.1012
# Epoch [27/500], Loss: 0.0162
# Epoch [27/500], Loss: 0.0223
# Epoch [27/500], Loss: 0.0254
# Epoch [27/500], Loss: 0.0126
# Epoch [27/500], Loss: 0.0104
# Epoch [27/500], Loss: 0.0104
# Epoch [27/500], Loss: 0.1065
# Epoch [27/500], Loss: 0.0063
# Epoch [27/500], Loss: 0.0067
# Epoch [27/500], Loss: 0.0050
# Epoch [27/500], Loss: 0.0021
# Epoch [27/500], Loss: 0.1458
# Epoch [27/500], Loss: 0.2404
# Epoch [27/500], Loss: 0.0064
# Epoch [27/500], Loss: 0.0092
# Epoch [27/500], Loss: 0.0119
# Epoch [27/500], Loss: 0.0092
# Epoch [27/500], Loss: 0.0125
# Epoch [27/500], Loss: 0.0150
# Epoch [27/500], Loss: 0.0233
# Epoch [28/500], Loss: 0.0112
# Epoch [28/500], Loss: 0.0106
# Epoch [28/500], Loss: 0.0064
# Epoch [28/500], Loss: 0.0033
# Epoch [28/500], Loss: 0.0041
# Epoch [28/500], Loss: 0.0024
# Epoch [28/500], Loss: 0.1398
# Epoch [28/500], Loss: 0.1456
# Epoch [28/500], Loss: 0.0027
# Epoch [28/500], Loss: 0.0029
# Epoch [28/500], Loss: 0.1258
# Epoch [28/500], Loss: 0.0023
# Epoch [28/500], Loss: 0.0031
# Epoch [28/500], Loss: 0.0135
# Epoch [28/500], Loss: 0.0114
# Epoch [28/500], Loss: 0.1033
# Epoch [28/500], Loss: 0.0085
# Epoch [28/500], Loss: 0.0032
# Epoch [28/500], Loss: 0.0960
# Epoch [28/500], Loss: 0.1082
# Epoch [28/500], Loss: 0.0098
# Epoch [28/500], Loss: 0.0197
# Epoch [28/500], Loss: 0.0158
# Epoch [28/500], Loss: 0.0907
# Epoch [28/500], Loss: 0.0194
# Epoch [28/500], Loss: 0.0099
# Epoch [28/500], Loss: 0.0150
# Epoch [28/500], Loss: 0.0089
# Epoch [28/500], Loss: 0.0086
# Epoch [28/500], Loss: 0.1090
# Epoch [28/500], Loss: 0.0060
# Epoch [28/500], Loss: 0.2146
# Epoch [28/500], Loss: 0.0002
# Epoch [29/500], Loss: 0.0112
# Epoch [29/500], Loss: 0.0088
# Epoch [29/500], Loss: 0.0811
# Epoch [29/500], Loss: 0.1744
# Epoch [29/500], Loss: 0.1013
# Epoch [29/500], Loss: 0.0292
# Epoch [29/500], Loss: 0.0277
# Epoch [29/500], Loss: 0.0226
# Epoch [29/500], Loss: 0.0091
# Epoch [29/500], Loss: 0.0879
# Epoch [29/500], Loss: 0.0224
# Epoch [29/500], Loss: 0.0078
# Epoch [29/500], Loss: 0.0103
# Epoch [29/500], Loss: 0.0241
# Epoch [29/500], Loss: 0.0035
# Epoch [29/500], Loss: 0.0161
# Epoch [29/500], Loss: 0.0091
# Epoch [29/500], Loss: 0.0032
# Epoch [29/500], Loss: 0.0042
# Epoch [29/500], Loss: 0.1905
# Epoch [29/500], Loss: 0.0009
# Epoch [29/500], Loss: 0.0016
# Epoch [29/500], Loss: 0.2706
# Epoch [29/500], Loss: 0.0015
# Epoch [29/500], Loss: 0.0054
# Epoch [29/500], Loss: 0.1041
# Epoch [29/500], Loss: 0.0097
# Epoch [29/500], Loss: 0.0089
# Epoch [29/500], Loss: 0.0218
# Epoch [29/500], Loss: 0.0206
# Epoch [29/500], Loss: 0.0196
# Epoch [29/500], Loss: 0.0798
# Epoch [29/500], Loss: 0.0079
# Epoch [30/500], Loss: 0.0113
# Epoch [30/500], Loss: 0.0090
# Epoch [30/500], Loss: 0.0056
# Epoch [30/500], Loss: 0.0960
# Epoch [30/500], Loss: 0.1003
# Epoch [30/500], Loss: 0.0071
# Epoch [30/500], Loss: 0.0053
# Epoch [30/500], Loss: 0.0122
# Epoch [30/500], Loss: 0.0049
# Epoch [30/500], Loss: 0.0081
# Epoch [30/500], Loss: 0.0064
# Epoch [30/500], Loss: 0.0072
# Epoch [30/500], Loss: 0.0068
# Epoch [30/500], Loss: 0.1357
# Epoch [30/500], Loss: 0.0057
# Epoch [30/500], Loss: 0.0037
# Epoch [30/500], Loss: 0.0048
# Epoch [30/500], Loss: 0.1070
# Epoch [30/500], Loss: 0.0042
# Epoch [30/500], Loss: 0.0039
# Epoch [30/500], Loss: 0.1264
# Epoch [30/500], Loss: 0.1210
# Epoch [30/500], Loss: 0.0036
# Epoch [30/500], Loss: 0.1206
# Epoch [30/500], Loss: 0.0095
# Epoch [30/500], Loss: 0.0135
# Epoch [30/500], Loss: 0.0945
# Epoch [30/500], Loss: 0.0745
# Epoch [30/500], Loss: 0.0309
# Epoch [30/500], Loss: 0.0302
# Epoch [30/500], Loss: 0.0805
# Epoch [30/500], Loss: 0.0209
# Epoch [30/500], Loss: 0.0196
# Epoch [31/500], Loss: 0.0256
# Epoch [31/500], Loss: 0.0919
# Epoch [31/500], Loss: 0.0040
# Epoch [31/500], Loss: 0.0997
# Epoch [31/500], Loss: 0.0125
# Epoch [31/500], Loss: 0.0067
# Epoch [31/500], Loss: 0.0094
# Epoch [31/500], Loss: 0.0037
# Epoch [31/500], Loss: 0.0072
# Epoch [31/500], Loss: 0.0041
# Epoch [31/500], Loss: 0.0013
# Epoch [31/500], Loss: 0.1219
# Epoch [31/500], Loss: 0.0014
# Epoch [31/500], Loss: 0.1277
# Epoch [31/500], Loss: 0.1220
# Epoch [31/500], Loss: 0.0980
# Epoch [31/500], Loss: 0.0067
# Epoch [31/500], Loss: 0.1019
# Epoch [31/500], Loss: 0.0287
# Epoch [31/500], Loss: 0.0078
# Epoch [31/500], Loss: 0.0269
# Epoch [31/500], Loss: 0.0211
# Epoch [31/500], Loss: 0.0175
# Epoch [31/500], Loss: 0.0986
# Epoch [31/500], Loss: 0.0193
# Epoch [31/500], Loss: 0.0113
# Epoch [31/500], Loss: 0.0222
# Epoch [31/500], Loss: 0.0094
# Epoch [31/500], Loss: 0.0928
# Epoch [31/500], Loss: 0.1021
# Epoch [31/500], Loss: 0.0099
# Epoch [31/500], Loss: 0.0088
# Epoch [31/500], Loss: 0.0079
# Epoch [32/500], Loss: 0.1035
# Epoch [32/500], Loss: 0.0019
# Epoch [32/500], Loss: 0.0043
# Epoch [32/500], Loss: 0.0035
# Epoch [32/500], Loss: 0.1262
# Epoch [32/500], Loss: 0.0068
# Epoch [32/500], Loss: 0.0070
# Epoch [32/500], Loss: 0.0031
# Epoch [32/500], Loss: 0.0043
# Epoch [32/500], Loss: 0.0028
# Epoch [32/500], Loss: 0.0020
# Epoch [32/500], Loss: 0.0045
# Epoch [32/500], Loss: 0.0009
# Epoch [32/500], Loss: 0.0021
# Epoch [32/500], Loss: 0.2764
# Epoch [32/500], Loss: 0.0035
# Epoch [32/500], Loss: 0.0093
# Epoch [32/500], Loss: 0.0808
# Epoch [32/500], Loss: 0.0811
# Epoch [32/500], Loss: 0.0441
# Epoch [32/500], Loss: 0.0302
# Epoch [32/500], Loss: 0.0383
# Epoch [32/500], Loss: 0.0188
# Epoch [32/500], Loss: 0.0902
# Epoch [32/500], Loss: 0.0117
# Epoch [32/500], Loss: 0.0055
# Epoch [32/500], Loss: 0.0083
# Epoch [32/500], Loss: 0.0057
# Epoch [32/500], Loss: 0.2533
# Epoch [32/500], Loss: 0.0037
# Epoch [32/500], Loss: 0.1156
# Epoch [32/500], Loss: 0.0057
# Epoch [32/500], Loss: 0.0056
# Epoch [33/500], Loss: 0.0050
# Epoch [33/500], Loss: 0.0107
# Epoch [33/500], Loss: 0.0086
# Epoch [33/500], Loss: 0.0081
# Epoch [33/500], Loss: 0.0076
# Epoch [33/500], Loss: 0.0058
# Epoch [33/500], Loss: 0.0081
# Epoch [33/500], Loss: 0.0041
# Epoch [33/500], Loss: 0.1149
# Epoch [33/500], Loss: 0.0036
# Epoch [33/500], Loss: 0.2193
# Epoch [33/500], Loss: 0.1110
# Epoch [33/500], Loss: 0.0059
# Epoch [33/500], Loss: 0.0081
# Epoch [33/500], Loss: 0.0081
# Epoch [33/500], Loss: 0.0126
# Epoch [33/500], Loss: 0.0156
# Epoch [33/500], Loss: 0.0247
# Epoch [33/500], Loss: 0.0146
# Epoch [33/500], Loss: 0.0064
# Epoch [33/500], Loss: 0.0118
# Epoch [33/500], Loss: 0.1009
# Epoch [33/500], Loss: 0.1011
# Epoch [33/500], Loss: 0.0103
# Epoch [33/500], Loss: 0.0088
# Epoch [33/500], Loss: 0.0976
# Epoch [33/500], Loss: 0.1091
# Epoch [33/500], Loss: 0.0080
# Epoch [33/500], Loss: 0.0854
# Epoch [33/500], Loss: 0.0112
# Epoch [33/500], Loss: 0.0975
# Epoch [33/500], Loss: 0.0104
# Epoch [33/500], Loss: 0.0215
# Epoch [34/500], Loss: 0.0157
# Epoch [34/500], Loss: 0.0062
# Epoch [34/500], Loss: 0.0092
# Epoch [34/500], Loss: 0.1105
# Epoch [34/500], Loss: 0.0108
# Epoch [34/500], Loss: 0.0157
# Epoch [34/500], Loss: 0.0129
# Epoch [34/500], Loss: 0.0054
# Epoch [34/500], Loss: 0.0910
# Epoch [34/500], Loss: 0.1059
# Epoch [34/500], Loss: 0.0081
# Epoch [34/500], Loss: 0.0077
# Epoch [34/500], Loss: 0.1028
# Epoch [34/500], Loss: 0.1049
# Epoch [34/500], Loss: 0.1091
# Epoch [34/500], Loss: 0.0105
# Epoch [34/500], Loss: 0.0149
# Epoch [34/500], Loss: 0.0069
# Epoch [34/500], Loss: 0.0149
# Epoch [34/500], Loss: 0.0816
# Epoch [34/500], Loss: 0.0181
# Epoch [34/500], Loss: 0.0927
# Epoch [34/500], Loss: 0.0848
# Epoch [34/500], Loss: 0.0053
# Epoch [34/500], Loss: 0.0071
# Epoch [34/500], Loss: 0.0095
# Epoch [34/500], Loss: 0.0046
# Epoch [34/500], Loss: 0.0919
# Epoch [34/500], Loss: 0.0043
# Epoch [34/500], Loss: 0.0049
# Epoch [34/500], Loss: 0.0104
# Epoch [34/500], Loss: 0.0072
# Epoch [34/500], Loss: 0.0093
# Epoch [35/500], Loss: 0.0050
# Epoch [35/500], Loss: 0.0046
# Epoch [35/500], Loss: 0.0025
# Epoch [35/500], Loss: 0.0018
# Epoch [35/500], Loss: 0.0011
# Epoch [35/500], Loss: 0.0007
# Epoch [35/500], Loss: 0.1537
# Epoch [35/500], Loss: 0.0004
# Epoch [35/500], Loss: 0.0003
# Epoch [35/500], Loss: 0.2154
# Epoch [35/500], Loss: 0.0009
# Epoch [35/500], Loss: 0.0020
# Epoch [35/500], Loss: 0.0046
# Epoch [35/500], Loss: 0.0034
# Epoch [35/500], Loss: 0.0141
# Epoch [35/500], Loss: 0.0653
# Epoch [35/500], Loss: 0.0170
# Epoch [35/500], Loss: 0.0885
# Epoch [35/500], Loss: 0.0163
# Epoch [35/500], Loss: 0.0057
# Epoch [35/500], Loss: 0.0118
# Epoch [35/500], Loss: 0.1016
# Epoch [35/500], Loss: 0.1118
# Epoch [35/500], Loss: 0.0963
# Epoch [35/500], Loss: 0.0084
# Epoch [35/500], Loss: 0.1944
# Epoch [35/500], Loss: 0.0074
# Epoch [35/500], Loss: 0.0772
# Epoch [35/500], Loss: 0.0181
# Epoch [35/500], Loss: 0.0276
# Epoch [35/500], Loss: 0.0088
# Epoch [35/500], Loss: 0.0894
# Epoch [35/500], Loss: 0.0391
# Epoch [36/500], Loss: 0.0145
# Epoch [36/500], Loss: 0.0240
# Epoch [36/500], Loss: 0.0125
# Epoch [36/500], Loss: 0.1867
# Epoch [36/500], Loss: 0.0082
# Epoch [36/500], Loss: 0.0072
# Epoch [36/500], Loss: 0.0075
# Epoch [36/500], Loss: 0.0041
# Epoch [36/500], Loss: 0.0028
# Epoch [36/500], Loss: 0.0037
# Epoch [36/500], Loss: 0.0040
# Epoch [36/500], Loss: 0.1383
# Epoch [36/500], Loss: 0.0025
# Epoch [36/500], Loss: 0.0014
# Epoch [36/500], Loss: 0.0028
# Epoch [36/500], Loss: 0.2728
# Epoch [36/500], Loss: 0.0032
# Epoch [36/500], Loss: 0.0041
# Epoch [36/500], Loss: 0.0091
# Epoch [36/500], Loss: 0.0041
# Epoch [36/500], Loss: 0.1031
# Epoch [36/500], Loss: 0.0084
# Epoch [36/500], Loss: 0.0966
# Epoch [36/500], Loss: 0.0954
# Epoch [36/500], Loss: 0.0819
# Epoch [36/500], Loss: 0.0251
# Epoch [36/500], Loss: 0.0689
# Epoch [36/500], Loss: 0.0193
# Epoch [36/500], Loss: 0.0243
# Epoch [36/500], Loss: 0.0609
# Epoch [36/500], Loss: 0.0313
# Epoch [36/500], Loss: 0.0133
# Epoch [36/500], Loss: 0.0001
# Epoch [37/500], Loss: 0.0236
# Epoch [37/500], Loss: 0.0142
# Epoch [37/500], Loss: 0.0858
# Epoch [37/500], Loss: 0.0053
# Epoch [37/500], Loss: 0.0059
# Epoch [37/500], Loss: 0.0088
# Epoch [37/500], Loss: 0.0052
# Epoch [37/500], Loss: 0.0036
# Epoch [37/500], Loss: 0.0040
# Epoch [37/500], Loss: 0.1260
# Epoch [37/500], Loss: 0.0041
# Epoch [37/500], Loss: 0.0034
# Epoch [37/500], Loss: 0.0075
# Epoch [37/500], Loss: 0.0086
# Epoch [37/500], Loss: 0.1405
# Epoch [37/500], Loss: 0.2645
# Epoch [37/500], Loss: 0.0055
# Epoch [37/500], Loss: 0.1061
# Epoch [37/500], Loss: 0.0064
# Epoch [37/500], Loss: 0.1200
# Epoch [37/500], Loss: 0.1130
# Epoch [37/500], Loss: 0.0280
# Epoch [37/500], Loss: 0.0431
# Epoch [37/500], Loss: 0.1111
# Epoch [37/500], Loss: 0.0175
# Epoch [37/500], Loss: 0.0339
# Epoch [37/500], Loss: 0.0818
# Epoch [37/500], Loss: 0.0288
# Epoch [37/500], Loss: 0.0944
# Epoch [37/500], Loss: 0.0216
# Epoch [37/500], Loss: 0.0226
# Epoch [37/500], Loss: 0.0128
# Epoch [37/500], Loss: 0.0019
# Epoch [38/500], Loss: 0.1032
# Epoch [38/500], Loss: 0.1072
# Epoch [38/500], Loss: 0.0138
# Epoch [38/500], Loss: 0.0290
# Epoch [38/500], Loss: 0.2048
# Epoch [38/500], Loss: 0.0182
# Epoch [38/500], Loss: 0.0105
# Epoch [38/500], Loss: 0.0063
# Epoch [38/500], Loss: 0.0172
# Epoch [38/500], Loss: 0.0128
# Epoch [38/500], Loss: 0.0098
# Epoch [38/500], Loss: 0.0944
# Epoch [38/500], Loss: 0.0029
# Epoch [38/500], Loss: 0.1031
# Epoch [38/500], Loss: 0.0123
# Epoch [38/500], Loss: 0.0111
# Epoch [38/500], Loss: 0.0850
# Epoch [38/500], Loss: 0.0072
# Epoch [38/500], Loss: 0.0228
# Epoch [38/500], Loss: 0.0955
# Epoch [38/500], Loss: 0.0071
# Epoch [38/500], Loss: 0.0083
# Epoch [38/500], Loss: 0.0142
# Epoch [38/500], Loss: 0.0124
# Epoch [38/500], Loss: 0.0061
# Epoch [38/500], Loss: 0.0078
# Epoch [38/500], Loss: 0.0075
# Epoch [38/500], Loss: 0.0081
# Epoch [38/500], Loss: 0.1259
# Epoch [38/500], Loss: 0.0058
# Epoch [38/500], Loss: 0.0907
# Epoch [38/500], Loss: 0.0060
# Epoch [38/500], Loss: 0.0007
# Epoch [39/500], Loss: 0.2141
# Epoch [39/500], Loss: 0.0067
# Epoch [39/500], Loss: 0.0055
# Epoch [39/500], Loss: 0.0086
# Epoch [39/500], Loss: 0.0076
# Epoch [39/500], Loss: 0.0091
# Epoch [39/500], Loss: 0.0125
# Epoch [39/500], Loss: 0.0130
# Epoch [39/500], Loss: 0.0124
# Epoch [39/500], Loss: 0.0068
# Epoch [39/500], Loss: 0.0083
# Epoch [39/500], Loss: 0.0171
# Epoch [39/500], Loss: 0.1165
# Epoch [39/500], Loss: 0.0045
# Epoch [39/500], Loss: 0.0054
# Epoch [39/500], Loss: 0.0045
# Epoch [39/500], Loss: 0.0077
# Epoch [39/500], Loss: 0.0034
# Epoch [39/500], Loss: 0.1240
# Epoch [39/500], Loss: 0.0039
# Epoch [39/500], Loss: 0.1383
# Epoch [39/500], Loss: 0.0013
# Epoch [39/500], Loss: 0.1285
# Epoch [39/500], Loss: 0.0944
# Epoch [39/500], Loss: 0.0017
# Epoch [39/500], Loss: 0.0883
# Epoch [39/500], Loss: 0.0108
# Epoch [39/500], Loss: 0.0147
# Epoch [39/500], Loss: 0.1004
# Epoch [39/500], Loss: 0.0260
# Epoch [39/500], Loss: 0.0170
# Epoch [39/500], Loss: 0.1015
# Epoch [39/500], Loss: 0.0149
# Epoch [40/500], Loss: 0.0793
# Epoch [40/500], Loss: 0.0344
# Epoch [40/500], Loss: 0.0954
# Epoch [40/500], Loss: 0.0832
# Epoch [40/500], Loss: 0.0113
# Epoch [40/500], Loss: 0.0186
# Epoch [40/500], Loss: 0.0119
# Epoch [40/500], Loss: 0.0154
# Epoch [40/500], Loss: 0.0994
# Epoch [40/500], Loss: 0.0104
# Epoch [40/500], Loss: 0.0043
# Epoch [40/500], Loss: 0.0094
# Epoch [40/500], Loss: 0.0084
# Epoch [40/500], Loss: 0.0035
# Epoch [40/500], Loss: 0.1167
# Epoch [40/500], Loss: 0.0026
# Epoch [40/500], Loss: 0.1405
# Epoch [40/500], Loss: 0.1320
# Epoch [40/500], Loss: 0.0033
# Epoch [40/500], Loss: 0.0057
# Epoch [40/500], Loss: 0.0100
# Epoch [40/500], Loss: 0.0127
# Epoch [40/500], Loss: 0.0062
# Epoch [40/500], Loss: 0.1286
# Epoch [40/500], Loss: 0.1130
# Epoch [40/500], Loss: 0.0046
# Epoch [40/500], Loss: 0.0063
# Epoch [40/500], Loss: 0.0111
# Epoch [40/500], Loss: 0.0023
# Epoch [40/500], Loss: 0.0043
# Epoch [40/500], Loss: 0.0968
# Epoch [40/500], Loss: 0.0129
# Epoch [40/500], Loss: 0.0045
# Epoch [41/500], Loss: 0.0949
# Epoch [41/500], Loss: 0.0062
# Epoch [41/500], Loss: 0.1011
# Epoch [41/500], Loss: 0.0897
# Epoch [41/500], Loss: 0.0963
# Epoch [41/500], Loss: 0.0262
# Epoch [41/500], Loss: 0.0192
# Epoch [41/500], Loss: 0.0987
# Epoch [41/500], Loss: 0.0265
# Epoch [41/500], Loss: 0.0153
# Epoch [41/500], Loss: 0.0752
# Epoch [41/500], Loss: 0.0216
# Epoch [41/500], Loss: 0.0898
# Epoch [41/500], Loss: 0.0042
# Epoch [41/500], Loss: 0.0157
# Epoch [41/500], Loss: 0.0818
# Epoch [41/500], Loss: 0.0119
# Epoch [41/500], Loss: 0.0100
# Epoch [41/500], Loss: 0.0195
# Epoch [41/500], Loss: 0.0129
# Epoch [41/500], Loss: 0.0127
# Epoch [41/500], Loss: 0.0072
# Epoch [41/500], Loss: 0.0028
# Epoch [41/500], Loss: 0.0014
# Epoch [41/500], Loss: 0.0019
# Epoch [41/500], Loss: 0.0006
# Epoch [41/500], Loss: 0.0007
# Epoch [41/500], Loss: 0.0006
# Epoch [41/500], Loss: 0.1969
# Epoch [41/500], Loss: 0.0005
# Epoch [41/500], Loss: 0.1420
# Epoch [41/500], Loss: 0.0004
# Epoch [41/500], Loss: 0.0010
# Epoch [42/500], Loss: 0.1457
# Epoch [42/500], Loss: 0.0020
# Epoch [42/500], Loss: 0.0025
# Epoch [42/500], Loss: 0.0029
# Epoch [42/500], Loss: 0.2143
# Epoch [42/500], Loss: 0.0058
# Epoch [42/500], Loss: 0.0108
# Epoch [42/500], Loss: 0.0171
# Epoch [42/500], Loss: 0.0177
# Epoch [42/500], Loss: 0.0146
# Epoch [42/500], Loss: 0.0282
# Epoch [42/500], Loss: 0.0169
# Epoch [42/500], Loss: 0.0188
# Epoch [42/500], Loss: 0.0125
# Epoch [42/500], Loss: 0.0069
# Epoch [42/500], Loss: 0.0027
# Epoch [42/500], Loss: 0.0054
# Epoch [42/500], Loss: 0.0042
# Epoch [42/500], Loss: 0.0033
# Epoch [42/500], Loss: 0.0050
# Epoch [42/500], Loss: 0.0006
# Epoch [42/500], Loss: 0.0012
# Epoch [42/500], Loss: 0.0008
# Epoch [42/500], Loss: 0.1841
# Epoch [42/500], Loss: 0.0010
# Epoch [42/500], Loss: 0.0010
# Epoch [42/500], Loss: 0.3066
# Epoch [42/500], Loss: 0.0019
# Epoch [42/500], Loss: 0.1269
# Epoch [42/500], Loss: 0.0042
# Epoch [42/500], Loss: 0.1671
# Epoch [42/500], Loss: 0.0832
# Epoch [42/500], Loss: 0.0504
# Epoch [43/500], Loss: 0.0251
# Epoch [43/500], Loss: 0.0341
# Epoch [43/500], Loss: 0.0965
# Epoch [43/500], Loss: 0.0079
# Epoch [43/500], Loss: 0.1235
# Epoch [43/500], Loss: 0.0306
# Epoch [43/500], Loss: 0.0215
# Epoch [43/500], Loss: 0.0639
# Epoch [43/500], Loss: 0.0195
# Epoch [43/500], Loss: 0.0172
# Epoch [43/500], Loss: 0.0100
# Epoch [43/500], Loss: 0.0035
# Epoch [43/500], Loss: 0.0009
# Epoch [43/500], Loss: 0.1768
# Epoch [43/500], Loss: 0.1452
# Epoch [43/500], Loss: 0.0022
# Epoch [43/500], Loss: 0.1470
# Epoch [43/500], Loss: 0.0049
# Epoch [43/500], Loss: 0.0065
# Epoch [43/500], Loss: 0.0082
# Epoch [43/500], Loss: 0.0102
# Epoch [43/500], Loss: 0.1011
# Epoch [43/500], Loss: 0.0080
# Epoch [43/500], Loss: 0.0174
# Epoch [43/500], Loss: 0.0909
# Epoch [43/500], Loss: 0.0147
# Epoch [43/500], Loss: 0.0128
# Epoch [43/500], Loss: 0.1033
# Epoch [43/500], Loss: 0.0229
# Epoch [43/500], Loss: 0.0224
# Epoch [43/500], Loss: 0.0075
# Epoch [43/500], Loss: 0.0103
# Epoch [43/500], Loss: 0.0156
# Epoch [44/500], Loss: 0.0904
# Epoch [44/500], Loss: 0.0045
# Epoch [44/500], Loss: 0.2024
# Epoch [44/500], Loss: 0.0052
# Epoch [44/500], Loss: 0.1135
# Epoch [44/500], Loss: 0.0124
# Epoch [44/500], Loss: 0.0092
# Epoch [44/500], Loss: 0.1961
# Epoch [44/500], Loss: 0.0177
# Epoch [44/500], Loss: 0.0891
# Epoch [44/500], Loss: 0.0151
# Epoch [44/500], Loss: 0.0223
# Epoch [44/500], Loss: 0.0773
# Epoch [44/500], Loss: 0.0197
# Epoch [44/500], Loss: 0.0941
# Epoch [44/500], Loss: 0.0641
# Epoch [44/500], Loss: 0.0121
# Epoch [44/500], Loss: 0.0162
# Epoch [44/500], Loss: 0.0216
# Epoch [44/500], Loss: 0.0149
# Epoch [44/500], Loss: 0.0224
# Epoch [44/500], Loss: 0.0047
# Epoch [44/500], Loss: 0.0048
# Epoch [44/500], Loss: 0.0087
# Epoch [44/500], Loss: 0.0049
# Epoch [44/500], Loss: 0.0041
# Epoch [44/500], Loss: 0.0031
# Epoch [44/500], Loss: 0.0024
# Epoch [44/500], Loss: 0.0016
# Epoch [44/500], Loss: 0.0011
# Epoch [44/500], Loss: 0.0006
# Epoch [44/500], Loss: 0.0004
# Epoch [44/500], Loss: 0.0003
# Epoch [45/500], Loss: 0.0002
# Epoch [45/500], Loss: 0.1646
# Epoch [45/500], Loss: 0.0004
# Epoch [45/500], Loss: 0.0008
# Epoch [45/500], Loss: 0.1807
# Epoch [45/500], Loss: 0.0006
# Epoch [45/500], Loss: 0.0015
# Epoch [45/500], Loss: 0.0017
# Epoch [45/500], Loss: 0.1232
# Epoch [45/500], Loss: 0.0025
# Epoch [45/500], Loss: 0.0033
# Epoch [45/500], Loss: 0.0049
# Epoch [45/500], Loss: 0.0028
# Epoch [45/500], Loss: 0.0085
# Epoch [45/500], Loss: 0.0105
# Epoch [45/500], Loss: 0.0118
# Epoch [45/500], Loss: 0.0102
# Epoch [45/500], Loss: 0.0081
# Epoch [45/500], Loss: 0.1086
# Epoch [45/500], Loss: 0.0086
# Epoch [45/500], Loss: 0.0949
# Epoch [45/500], Loss: 0.0081
# Epoch [45/500], Loss: 0.0066
# Epoch [45/500], Loss: 0.0097
# Epoch [45/500], Loss: 0.0997
# Epoch [45/500], Loss: 0.0776
# Epoch [45/500], Loss: 0.0158
# Epoch [45/500], Loss: 0.0824
# Epoch [45/500], Loss: 0.1062
# Epoch [45/500], Loss: 0.0892
# Epoch [45/500], Loss: 0.0119
# Epoch [45/500], Loss: 0.0263
# Epoch [45/500], Loss: 0.0153
# Epoch [46/500], Loss: 0.0226
# Epoch [46/500], Loss: 0.0903
# Epoch [46/500], Loss: 0.0141
# Epoch [46/500], Loss: 0.0144
# Epoch [46/500], Loss: 0.0754
# Epoch [46/500], Loss: 0.0084
# Epoch [46/500], Loss: 0.0118
# Epoch [46/500], Loss: 0.1079
# Epoch [46/500], Loss: 0.0092
# Epoch [46/500], Loss: 0.0964
# Epoch [46/500], Loss: 0.0082
# Epoch [46/500], Loss: 0.0053
# Epoch [46/500], Loss: 0.0063
# Epoch [46/500], Loss: 0.0901
# Epoch [46/500], Loss: 0.0079
# Epoch [46/500], Loss: 0.0042
# Epoch [46/500], Loss: 0.0954
# Epoch [46/500], Loss: 0.0016
# Epoch [46/500], Loss: 0.0942
# Epoch [46/500], Loss: 0.0092
# Epoch [46/500], Loss: 0.0089
# Epoch [46/500], Loss: 0.0118
# Epoch [46/500], Loss: 0.0092
# Epoch [46/500], Loss: 0.0093
# Epoch [46/500], Loss: 0.0092
# Epoch [46/500], Loss: 0.0066
# Epoch [46/500], Loss: 0.1049
# Epoch [46/500], Loss: 0.1146
# Epoch [46/500], Loss: 0.0051
# Epoch [46/500], Loss: 0.0142
# Epoch [46/500], Loss: 0.0067
# Epoch [46/500], Loss: 0.0753
# Epoch [46/500], Loss: 0.0001
# Epoch [47/500], Loss: 0.0957
# Epoch [47/500], Loss: 0.0061
# Epoch [47/500], Loss: 0.0733
# Epoch [47/500], Loss: 0.0780
# Epoch [47/500], Loss: 0.0201
# Epoch [47/500], Loss: 0.0888
# Epoch [47/500], Loss: 0.0050
# Epoch [47/500], Loss: 0.0282
# Epoch [47/500], Loss: 0.0131
# Epoch [47/500], Loss: 0.0104
# Epoch [47/500], Loss: 0.0088
# Epoch [47/500], Loss: 0.0104
# Epoch [47/500], Loss: 0.0025
# Epoch [47/500], Loss: 0.0077
# Epoch [47/500], Loss: 0.0043
# Epoch [47/500], Loss: 0.0068
# Epoch [47/500], Loss: 0.0020
# Epoch [47/500], Loss: 0.0015
# Epoch [47/500], Loss: 0.1022
# Epoch [47/500], Loss: 0.0028
# Epoch [47/500], Loss: 0.1132
# Epoch [47/500], Loss: 0.0022
# Epoch [47/500], Loss: 0.0040
# Epoch [47/500], Loss: 0.0017
# Epoch [47/500], Loss: 0.1007
# Epoch [47/500], Loss: 0.1448
# Epoch [47/500], Loss: 0.0092
# Epoch [47/500], Loss: 0.0907
# Epoch [47/500], Loss: 0.0105
# Epoch [47/500], Loss: 0.0092
# Epoch [47/500], Loss: 0.0271
# Epoch [47/500], Loss: 0.0314
# Epoch [47/500], Loss: 0.3950
# Epoch [48/500], Loss: 0.0454
# Epoch [48/500], Loss: 0.0442
# Epoch [48/500], Loss: 0.0701
# Epoch [48/500], Loss: 0.0312
# Epoch [48/500], Loss: 0.0339
# Epoch [48/500], Loss: 0.0148
# Epoch [48/500], Loss: 0.0132
# Epoch [48/500], Loss: 0.0034
# Epoch [48/500], Loss: 0.0778
# Epoch [48/500], Loss: 0.0026
# Epoch [48/500], Loss: 0.1237
# Epoch [48/500], Loss: 0.0018
# Epoch [48/500], Loss: 0.2646
# Epoch [48/500], Loss: 0.0034
# Epoch [48/500], Loss: 0.0049
# Epoch [48/500], Loss: 0.0082
# Epoch [48/500], Loss: 0.0947
# Epoch [48/500], Loss: 0.0060
# Epoch [48/500], Loss: 0.0059
# Epoch [48/500], Loss: 0.0744
# Epoch [48/500], Loss: 0.0160
# Epoch [48/500], Loss: 0.0114
# Epoch [48/500], Loss: 0.0888
# Epoch [48/500], Loss: 0.0112
# Epoch [48/500], Loss: 0.0219
# Epoch [48/500], Loss: 0.1133
# Epoch [48/500], Loss: 0.0221
# Epoch [48/500], Loss: 0.0097
# Epoch [48/500], Loss: 0.0107
# Epoch [48/500], Loss: 0.0915
# Epoch [48/500], Loss: 0.0081
# Epoch [48/500], Loss: 0.1227
# Epoch [48/500], Loss: 0.0000
# Epoch [49/500], Loss: 0.1173
# Epoch [49/500], Loss: 0.0056
# Epoch [49/500], Loss: 0.0919
# Epoch [49/500], Loss: 0.0083
# Epoch [49/500], Loss: 0.0134
# Epoch [49/500], Loss: 0.0120
# Epoch [49/500], Loss: 0.0101
# Epoch [49/500], Loss: 0.0107
# Epoch [49/500], Loss: 0.0092
# Epoch [49/500], Loss: 0.0099
# Epoch [49/500], Loss: 0.0866
# Epoch [49/500], Loss: 0.1533
# Epoch [49/500], Loss: 0.1990
# Epoch [49/500], Loss: 0.0089
# Epoch [49/500], Loss: 0.0872
# Epoch [49/500], Loss: 0.0834
# Epoch [49/500], Loss: 0.0201
# Epoch [49/500], Loss: 0.0209
# Epoch [49/500], Loss: 0.0776
# Epoch [49/500], Loss: 0.0248
# Epoch [49/500], Loss: 0.0272
# Epoch [49/500], Loss: 0.0340
# Epoch [49/500], Loss: 0.0108
# Epoch [49/500], Loss: 0.0214
# Epoch [49/500], Loss: 0.0158
# Epoch [49/500], Loss: 0.0073
# Epoch [49/500], Loss: 0.0071
# Epoch [49/500], Loss: 0.0029
# Epoch [49/500], Loss: 0.1091
# Epoch [49/500], Loss: 0.0026
# Epoch [49/500], Loss: 0.0022
# Epoch [49/500], Loss: 0.0011
# Epoch [49/500], Loss: 0.0017
# Epoch [50/500], Loss: 0.0007
# Epoch [50/500], Loss: 0.0005
# Epoch [50/500], Loss: 0.4086
# Epoch [50/500], Loss: 0.0010
# Epoch [50/500], Loss: 0.0040
# Epoch [50/500], Loss: 0.0042
# Epoch [50/500], Loss: 0.0043
# Epoch [50/500], Loss: 0.0068
# Epoch [50/500], Loss: 0.0930
# Epoch [50/500], Loss: 0.0811
# Epoch [50/500], Loss: 0.0938
# Epoch [50/500], Loss: 0.0213
# Epoch [50/500], Loss: 0.0889
# Epoch [50/500], Loss: 0.0284
# Epoch [50/500], Loss: 0.0662
# Epoch [50/500], Loss: 0.0130
# Epoch [50/500], Loss: 0.0251
# Epoch [50/500], Loss: 0.0110
# Epoch [50/500], Loss: 0.0190
# Epoch [50/500], Loss: 0.0461
# Epoch [50/500], Loss: 0.0174
# Epoch [50/500], Loss: 0.0137
# Epoch [50/500], Loss: 0.0203
# Epoch [50/500], Loss: 0.0112
# Epoch [50/500], Loss: 0.0143
# Epoch [50/500], Loss: 0.0945
# Epoch [50/500], Loss: 0.0086
# Epoch [50/500], Loss: 0.0056
# Epoch [50/500], Loss: 0.1176
# Epoch [50/500], Loss: 0.0986
# Epoch [50/500], Loss: 0.0040
# Epoch [50/500], Loss: 0.0060
# Epoch [50/500], Loss: 0.0039
# Epoch [51/500], Loss: 0.0029
# Epoch [51/500], Loss: 0.0886
# Epoch [51/500], Loss: 0.0051
# Epoch [51/500], Loss: 0.0060
# Epoch [51/500], Loss: 0.0048
# Epoch [51/500], Loss: 0.0046
# Epoch [51/500], Loss: 0.0035
# Epoch [51/500], Loss: 0.0069
# Epoch [51/500], Loss: 0.0050
# Epoch [51/500], Loss: 0.0004
# Epoch [51/500], Loss: 0.1126
# Epoch [51/500], Loss: 0.0060
# Epoch [51/500], Loss: 0.0025
# Epoch [51/500], Loss: 0.0029
# Epoch [51/500], Loss: 0.0070
# ...
# Epoch [484/500], Loss: 0.0060
# Epoch [484/500], Loss: 0.0063
# Epoch [484/500], Loss: 0.0112
# Epoch [484/500], Loss: 0.0083
# Epoch [484/500], Loss: 0.0209
# Epoch [485/500], Loss: 0.0047
# Epoch [485/500], Loss: 0.0196
# Epoch [485/500], Loss: 0.0048
# Epoch [485/500], Loss: 0.0307
# Epoch [485/500], Loss: 0.0072
# Epoch [485/500], Loss: 0.0181
# Epoch [485/500], Loss: 0.1946
# Epoch [485/500], Loss: 0.0688
# Epoch [485/500], Loss: 0.0038
# Epoch [485/500], Loss: 0.0070
# Epoch [485/500], Loss: 0.0055
# Epoch [485/500], Loss: 0.0075
# Epoch [485/500], Loss: 0.0181
# Epoch [485/500], Loss: 0.0045
# Epoch [485/500], Loss: 0.0060
# Epoch [485/500], Loss: 0.0109
# Epoch [485/500], Loss: 0.0014
# Epoch [485/500], Loss: 0.1409
# Epoch [485/500], Loss: 0.0351
# Epoch [485/500], Loss: 0.0322
# Epoch [485/500], Loss: 0.1134
# Epoch [485/500], Loss: 0.0043
# Epoch [485/500], Loss: 0.0060
# Epoch [485/500], Loss: 0.0078
# Epoch [485/500], Loss: 0.0976
# Epoch [485/500], Loss: 0.0028
# Epoch [485/500], Loss: 0.0026
# Epoch [485/500], Loss: 0.0997
# Epoch [485/500], Loss: 0.0029
# Epoch [485/500], Loss: 0.0042
# Epoch [485/500], Loss: 0.1319
# Epoch [485/500], Loss: 0.0033
# Epoch [485/500], Loss: 0.0000
# Epoch [486/500], Loss: 0.0051
# Epoch [486/500], Loss: 0.0059
# Epoch [486/500], Loss: 0.0034
# Epoch [486/500], Loss: 0.0089
# Epoch [486/500], Loss: 0.0033
# Epoch [486/500], Loss: 0.0091
# Epoch [486/500], Loss: 0.0051
# Epoch [486/500], Loss: 0.0043
# Epoch [486/500], Loss: 0.0044
# Epoch [486/500], Loss: 0.0076
# Epoch [486/500], Loss: 0.0022
# Epoch [486/500], Loss: 0.0039
# Epoch [486/500], Loss: 0.0115
# Epoch [486/500], Loss: 0.0041
# Epoch [486/500], Loss: 0.0030
# Epoch [486/500], Loss: 0.0993
# Epoch [486/500], Loss: 0.0046
# Epoch [486/500], Loss: 0.0046
# Epoch [486/500], Loss: 0.0093
# Epoch [486/500], Loss: 0.1003
# Epoch [486/500], Loss: 0.0013
# Epoch [486/500], Loss: 0.0049
# Epoch [486/500], Loss: 0.1907
# Epoch [486/500], Loss: 0.1681
# Epoch [486/500], Loss: 0.0056
# Epoch [486/500], Loss: 0.0094
# Epoch [486/500], Loss: 0.0034
# Epoch [486/500], Loss: 0.1236
# Epoch [486/500], Loss: 0.1279
# Epoch [486/500], Loss: 0.1012
# Epoch [486/500], Loss: 0.0046
# Epoch [486/500], Loss: 0.0227
# Epoch [486/500], Loss: 0.0085
# Epoch [487/500], Loss: 0.0887
# Epoch [487/500], Loss: 0.0192
# Epoch [487/500], Loss: 0.0202
# Epoch [487/500], Loss: 0.0548
# Epoch [487/500], Loss: 0.0132
# Epoch [487/500], Loss: 0.1289
# Epoch [487/500], Loss: 0.0196
# Epoch [487/500], Loss: 0.0060
# Epoch [487/500], Loss: 0.0157
# Epoch [487/500], Loss: 0.0111
# Epoch [487/500], Loss: 0.0054
# Epoch [487/500], Loss: 0.0272
# Epoch [487/500], Loss: 0.0097
# Epoch [487/500], Loss: 0.0084
# Epoch [487/500], Loss: 0.0022
# Epoch [487/500], Loss: 0.0035
# Epoch [487/500], Loss: 0.0034
# Epoch [487/500], Loss: 0.0022
# Epoch [487/500], Loss: 0.0093
# Epoch [487/500], Loss: 0.0030
# Epoch [487/500], Loss: 0.0933
# Epoch [487/500], Loss: 0.0021
# Epoch [487/500], Loss: 0.0023
# Epoch [487/500], Loss: 0.0018
# Epoch [487/500], Loss: 0.0836
# Epoch [487/500], Loss: 0.0018
# Epoch [487/500], Loss: 0.0844
# Epoch [487/500], Loss: 0.1066
# Epoch [487/500], Loss: 0.0045
# Epoch [487/500], Loss: 0.0007
# Epoch [487/500], Loss: 0.0033
# Epoch [487/500], Loss: 0.1077
# Epoch [487/500], Loss: 0.0059
# Epoch [488/500], Loss: 0.1084
# Epoch [488/500], Loss: 0.0018
# Epoch [488/500], Loss: 0.1526
# Epoch [488/500], Loss: 0.0047
# Epoch [488/500], Loss: 0.0209
# Epoch [488/500], Loss: 0.0059
# Epoch [488/500], Loss: 0.0070
# Epoch [488/500], Loss: 0.2094
# Epoch [488/500], Loss: 0.0066
# Epoch [488/500], Loss: 0.0066
# Epoch [488/500], Loss: 0.0100
# Epoch [488/500], Loss: 0.0107
# Epoch [488/500], Loss: 0.0026
# Epoch [488/500], Loss: 0.0202
# Epoch [488/500], Loss: 0.0106
# Epoch [488/500], Loss: 0.0086
# Epoch [488/500], Loss: 0.0554
# Epoch [488/500], Loss: 0.0093
# Epoch [488/500], Loss: 0.0241
# Epoch [488/500], Loss: 0.0060
# Epoch [488/500], Loss: 0.0131
# Epoch [488/500], Loss: 0.0026
# Epoch [488/500], Loss: 0.0036
# Epoch [488/500], Loss: 0.0043
# Epoch [488/500], Loss: 0.0088
# Epoch [488/500], Loss: 0.0024
# Epoch [488/500], Loss: 0.0394
# Epoch [488/500], Loss: 0.0499
# Epoch [488/500], Loss: 0.0593
# Epoch [488/500], Loss: 0.0068
# Epoch [488/500], Loss: 0.0044
# Epoch [488/500], Loss: 0.0042
# Epoch [488/500], Loss: 0.0003
# Epoch [489/500], Loss: 0.0053
# Epoch [489/500], Loss: 0.0038
# Epoch [489/500], Loss: 0.0029
# Epoch [489/500], Loss: 0.1241
# Epoch [489/500], Loss: 0.0043
# Epoch [489/500], Loss: 0.0144
# Epoch [489/500], Loss: 0.0035
# Epoch [489/500], Loss: 0.0047
# Epoch [489/500], Loss: 0.0044
# Epoch [489/500], Loss: 0.0030
# Epoch [489/500], Loss: 0.1182
# Epoch [489/500], Loss: 0.0032
# Epoch [489/500], Loss: 0.0039
# Epoch [489/500], Loss: 0.0108
# Epoch [489/500], Loss: 0.0017
# Epoch [489/500], Loss: 0.0026
# Epoch [489/500], Loss: 0.0012
# Epoch [489/500], Loss: 0.0031
# Epoch [489/500], Loss: 0.1582
# Epoch [489/500], Loss: 0.0022
# Epoch [489/500], Loss: 0.0115
# Epoch [489/500], Loss: 0.1942
# Epoch [489/500], Loss: 0.0040
# Epoch [489/500], Loss: 0.0557
# Epoch [489/500], Loss: 0.0038
# Epoch [489/500], Loss: 0.0124
# Epoch [489/500], Loss: 0.0041
# Epoch [489/500], Loss: 0.0079
# Epoch [489/500], Loss: 0.0272
# Epoch [489/500], Loss: 0.0484
# Epoch [489/500], Loss: 0.0037
# Epoch [489/500], Loss: 0.0170
# Epoch [489/500], Loss: 0.0000
# Epoch [490/500], Loss: 0.0032
# Epoch [490/500], Loss: 0.0053
# Epoch [490/500], Loss: 0.0080
# Epoch [490/500], Loss: 0.0062
# Epoch [490/500], Loss: 0.0099
# Epoch [490/500], Loss: 0.0102
# Epoch [490/500], Loss: 0.0043
# Epoch [490/500], Loss: 0.0035
# Epoch [490/500], Loss: 0.0736
# Epoch [490/500], Loss: 0.0066
# Epoch [490/500], Loss: 0.0052
# Epoch [490/500], Loss: 0.0083
# Epoch [490/500], Loss: 0.0008
# Epoch [490/500], Loss: 0.0649
# Epoch [490/500], Loss: 0.0051
# Epoch [490/500], Loss: 0.1232
# Epoch [490/500], Loss: 0.0047
# Epoch [490/500], Loss: 0.0072
# Epoch [490/500], Loss: 0.0075
# Epoch [490/500], Loss: 0.0064
# Epoch [490/500], Loss: 0.0054
# Epoch [490/500], Loss: 0.0010
# Epoch [490/500], Loss: 0.0985
# Epoch [490/500], Loss: 0.0039
# Epoch [490/500], Loss: 0.0024
# Epoch [490/500], Loss: 0.0025
# Epoch [490/500], Loss: 0.0747
# Epoch [490/500], Loss: 0.1687
# Epoch [490/500], Loss: 0.0202
# Epoch [490/500], Loss: 0.0740
# Epoch [490/500], Loss: 0.0047
# Epoch [490/500], Loss: 0.0133
# Epoch [490/500], Loss: 0.0000
# Epoch [491/500], Loss: 0.0084
# Epoch [491/500], Loss: 0.0781
# Epoch [491/500], Loss: 0.0101
# Epoch [491/500], Loss: 0.0210
# Epoch [491/500], Loss: 0.0858
# Epoch [491/500], Loss: 0.0071
# Epoch [491/500], Loss: 0.0155
# Epoch [491/500], Loss: 0.0169
# Epoch [491/500], Loss: 0.0071
# Epoch [491/500], Loss: 0.0708
# Epoch [491/500], Loss: 0.0056
# Epoch [491/500], Loss: 0.0082
# Epoch [491/500], Loss: 0.0027
# Epoch [491/500], Loss: 0.0013
# Epoch [491/500], Loss: 0.0077
# Epoch [491/500], Loss: 0.0079
# Epoch [491/500], Loss: 0.1176
# Epoch [491/500], Loss: 0.0025
# Epoch [491/500], Loss: 0.0025
# Epoch [491/500], Loss: 0.1265
# Epoch [491/500], Loss: 0.0051
# Epoch [491/500], Loss: 0.0068
# Epoch [491/500], Loss: 0.0046
# Epoch [491/500], Loss: 0.0335
# Epoch [491/500], Loss: 0.0720
# Epoch [491/500], Loss: 0.0016
# Epoch [491/500], Loss: 0.1002
# Epoch [491/500], Loss: 0.0037
# Epoch [491/500], Loss: 0.0005
# Epoch [491/500], Loss: 0.0096
# Epoch [491/500], Loss: 0.0039
# Epoch [491/500], Loss: 0.0044
# Epoch [491/500], Loss: 0.0000
# Epoch [492/500], Loss: 0.0152
# Epoch [492/500], Loss: 0.0076
# Epoch [492/500], Loss: 0.0079
# Epoch [492/500], Loss: 0.0081
# Epoch [492/500], Loss: 0.2090
# Epoch [492/500], Loss: 0.0365
# Epoch [492/500], Loss: 0.0115
# Epoch [492/500], Loss: 0.0024
# Epoch [492/500], Loss: 0.0038
# Epoch [492/500], Loss: 0.0082
# Epoch [492/500], Loss: 0.0576
# Epoch [492/500], Loss: 0.0029
# Epoch [492/500], Loss: 0.0067
# Epoch [492/500], Loss: 0.0242
# Epoch [492/500], Loss: 0.0039
# Epoch [492/500], Loss: 0.0224
# Epoch [492/500], Loss: 0.0034
# Epoch [492/500], Loss: 0.0662
# Epoch [492/500], Loss: 0.0119
# Epoch [492/500], Loss: 0.0022
# Epoch [492/500], Loss: 0.0058
# Epoch [492/500], Loss: 0.0045
# Epoch [492/500], Loss: 0.0060
# Epoch [492/500], Loss: 0.0100
# Epoch [492/500], Loss: 0.0057
# Epoch [492/500], Loss: 0.0415
# Epoch [492/500], Loss: 0.0016
# Epoch [492/500], Loss: 0.0012
# Epoch [492/500], Loss: 0.0084
# Epoch [492/500], Loss: 0.0019
# Epoch [492/500], Loss: 0.0101
# Epoch [492/500], Loss: 0.0021
# Epoch [492/500], Loss: 0.0003
# Epoch [493/500], Loss: 0.0045
# Epoch [493/500], Loss: 0.0010
# Epoch [493/500], Loss: 0.0027
# Epoch [493/500], Loss: 0.0051
# Epoch [493/500], Loss: 0.0015
# Epoch [493/500], Loss: 0.0008
# Epoch [493/500], Loss: 0.0133
# Epoch [493/500], Loss: 0.0209
# Epoch [493/500], Loss: 0.0326
# Epoch [493/500], Loss: 0.0195
# Epoch [493/500], Loss: 0.0001
# Epoch [493/500], Loss: 0.1868
# Epoch [493/500], Loss: 0.0006
# Epoch [493/500], Loss: 0.0009
# Epoch [493/500], Loss: 0.0014
# Epoch [493/500], Loss: 0.0204
# Epoch [493/500], Loss: 0.0016
# Epoch [493/500], Loss: 0.0930
# Epoch [493/500], Loss: 0.0057
# Epoch [493/500], Loss: 0.0051
# Epoch [493/500], Loss: 0.0083
# Epoch [493/500], Loss: 0.0069
# Epoch [493/500], Loss: 0.0046
# Epoch [493/500], Loss: 0.0049
# Epoch [493/500], Loss: 0.0010
# Epoch [493/500], Loss: 0.0122
# Epoch [493/500], Loss: 0.0006
# Epoch [493/500], Loss: 0.1624
# Epoch [493/500], Loss: 0.0009
# Epoch [493/500], Loss: 0.0034
# Epoch [493/500], Loss: 0.0775
# Epoch [493/500], Loss: 0.0012
# Epoch [493/500], Loss: 0.0000
# Epoch [494/500], Loss: 0.0057
# Epoch [494/500], Loss: 0.0042
# Epoch [494/500], Loss: 0.0011
# Epoch [494/500], Loss: 0.0317
# Epoch [494/500], Loss: 0.0066
# Epoch [494/500], Loss: 0.0026
# Epoch [494/500], Loss: 0.0057
# Epoch [494/500], Loss: 0.0052
# Epoch [494/500], Loss: 0.1572
# Epoch [494/500], Loss: 0.0050
# Epoch [494/500], Loss: 0.0477
# Epoch [494/500], Loss: 0.0020
# Epoch [494/500], Loss: 0.0040
# Epoch [494/500], Loss: 0.0026
# Epoch [494/500], Loss: 0.0012
# Epoch [494/500], Loss: 0.0091
# Epoch [494/500], Loss: 0.0061
# Epoch [494/500], Loss: 0.0037
# Epoch [494/500], Loss: 0.0028
# Epoch [494/500], Loss: 0.0077
# Epoch [494/500], Loss: 0.1888
# Epoch [494/500], Loss: 0.0045
# Epoch [494/500], Loss: 0.0047
# Epoch [494/500], Loss: 0.0103
# Epoch [494/500], Loss: 0.0179
# Epoch [494/500], Loss: 0.0049
# Epoch [494/500], Loss: 0.0029
# Epoch [494/500], Loss: 0.0026
# Epoch [494/500], Loss: 0.0016
# Epoch [494/500], Loss: 0.0456
# Epoch [494/500], Loss: 0.0568
# Epoch [494/500], Loss: 0.0060
# Epoch [494/500], Loss: 0.0000
# Epoch [495/500], Loss: 0.0012
# Epoch [495/500], Loss: 0.0051
# Epoch [495/500], Loss: 0.0022
# Epoch [495/500], Loss: 0.0020
# Epoch [495/500], Loss: 0.0093
# Epoch [495/500], Loss: 0.0032
# Epoch [495/500], Loss: 0.0044
# Epoch [495/500], Loss: 0.0015
# Epoch [495/500], Loss: 0.0376
# Epoch [495/500], Loss: 0.0049
# Epoch [495/500], Loss: 0.0032
# Epoch [495/500], Loss: 0.0029
# Epoch [495/500], Loss: 0.0282
# Epoch [495/500], Loss: 0.0035
# Epoch [495/500], Loss: 0.0001
# Epoch [495/500], Loss: 0.0004
# Epoch [495/500], Loss: 0.1765
# Epoch [495/500], Loss: 0.1425
# Epoch [495/500], Loss: 0.2234
# Epoch [495/500], Loss: 0.0106
# Epoch [495/500], Loss: 0.0074
# Epoch [495/500], Loss: 0.0654
# Epoch [495/500], Loss: 0.0716
# Epoch [495/500], Loss: 0.0161
# Epoch [495/500], Loss: 0.0398
# Epoch [495/500], Loss: 0.0523
# Epoch [495/500], Loss: 0.0399
# Epoch [495/500], Loss: 0.0198
# Epoch [495/500], Loss: 0.0255
# Epoch [495/500], Loss: 0.0067
# Epoch [495/500], Loss: 0.0274
# Epoch [495/500], Loss: 0.0257
# Epoch [495/500], Loss: 0.0155
# Epoch [496/500], Loss: 0.0090
# Epoch [496/500], Loss: 0.0053
# Epoch [496/500], Loss: 0.0827
# Epoch [496/500], Loss: 0.0087
# Epoch [496/500], Loss: 0.0039
# Epoch [496/500], Loss: 0.0034
# Epoch [496/500], Loss: 0.0053
# Epoch [496/500], Loss: 0.0047
# Epoch [496/500], Loss: 0.0030
# Epoch [496/500], Loss: 0.0033
# Epoch [496/500], Loss: 0.0894
# Epoch [496/500], Loss: 0.0046
# Epoch [496/500], Loss: 0.0032
# Epoch [496/500], Loss: 0.0013
# Epoch [496/500], Loss: 0.1076
# Epoch [496/500], Loss: 0.0025
# Epoch [496/500], Loss: 0.0049
# Epoch [496/500], Loss: 0.0021
# Epoch [496/500], Loss: 0.0019
# Epoch [496/500], Loss: 0.0031
# Epoch [496/500], Loss: 0.0084
# Epoch [496/500], Loss: 0.0198
# Epoch [496/500], Loss: 0.0962
# Epoch [496/500], Loss: 0.0027
# Epoch [496/500], Loss: 0.0057
# Epoch [496/500], Loss: 0.0045
# Epoch [496/500], Loss: 0.0292
# Epoch [496/500], Loss: 0.0419
# Epoch [496/500], Loss: 0.0048
# Epoch [496/500], Loss: 0.0891
# Epoch [496/500], Loss: 0.0134
# Epoch [496/500], Loss: 0.0071
# Epoch [496/500], Loss: 0.0061
# Epoch [497/500], Loss: 0.0016
# Epoch [497/500], Loss: 0.0075
# Epoch [497/500], Loss: 0.0026
# Epoch [497/500], Loss: 0.0058
# Epoch [497/500], Loss: 0.0388
# Epoch [497/500], Loss: 0.1244
# Epoch [497/500], Loss: 0.0016
# Epoch [497/500], Loss: 0.0009
# Epoch [497/500], Loss: 0.0048
# Epoch [497/500], Loss: 0.0070
# Epoch [497/500], Loss: 0.0010
# Epoch [497/500], Loss: 0.1050
# Epoch [497/500], Loss: 0.0029
# Epoch [497/500], Loss: 0.0084
# Epoch [497/500], Loss: 0.0014
# Epoch [497/500], Loss: 0.1430
# Epoch [497/500], Loss: 0.0095
# Epoch [497/500], Loss: 0.0024
# Epoch [497/500], Loss: 0.0032
# Epoch [497/500], Loss: 0.0065
# Epoch [497/500], Loss: 0.0989
# Epoch [497/500], Loss: 0.0086
# Epoch [497/500], Loss: 0.0145
# Epoch [497/500], Loss: 0.0102
# Epoch [497/500], Loss: 0.0371
# Epoch [497/500], Loss: 0.0047
# Epoch [497/500], Loss: 0.0038
# Epoch [497/500], Loss: 0.0076
# Epoch [497/500], Loss: 0.0872
# Epoch [497/500], Loss: 0.0042
# Epoch [497/500], Loss: 0.0072
# Epoch [497/500], Loss: 0.0055
# Epoch [497/500], Loss: 0.0056
# Epoch [498/500], Loss: 0.0035
# Epoch [498/500], Loss: 0.0095
# Epoch [498/500], Loss: 0.0363
# Epoch [498/500], Loss: 0.1217
# Epoch [498/500], Loss: 0.0722
# Epoch [498/500], Loss: 0.0014
# Epoch [498/500], Loss: 0.0319
# Epoch [498/500], Loss: 0.0103
# Epoch [498/500], Loss: 0.0024
# Epoch [498/500], Loss: 0.0076
# Epoch [498/500], Loss: 0.0039
# Epoch [498/500], Loss: 0.0022
# Epoch [498/500], Loss: 0.0040
# Epoch [498/500], Loss: 0.0034
# Epoch [498/500], Loss: 0.0036
# Epoch [498/500], Loss: 0.0037
# Epoch [498/500], Loss: 0.0572
# Epoch [498/500], Loss: 0.0008
# Epoch [498/500], Loss: 0.0043
# Epoch [498/500], Loss: 0.0177
# Epoch [498/500], Loss: 0.0054
# Epoch [498/500], Loss: 0.0017
# Epoch [498/500], Loss: 0.0039
# Epoch [498/500], Loss: 0.0020
# Epoch [498/500], Loss: 0.0025
# Epoch [498/500], Loss: 0.0039
# Epoch [498/500], Loss: 0.1251
# Epoch [498/500], Loss: 0.0029
# Epoch [498/500], Loss: 0.0022
# Epoch [498/500], Loss: 0.0504
# Epoch [498/500], Loss: 0.0071
# Epoch [498/500], Loss: 0.1112
# Epoch [498/500], Loss: 0.0000
# Epoch [499/500], Loss: 0.0013
# Epoch [499/500], Loss: 0.0041
# Epoch [499/500], Loss: 0.0034
# Epoch [499/500], Loss: 0.0002
# Epoch [499/500], Loss: 0.0086
# Epoch [499/500], Loss: 0.0138
# Epoch [499/500], Loss: 0.0850
# Epoch [499/500], Loss: 0.0013
# Epoch [499/500], Loss: 0.0012
# Epoch [499/500], Loss: 0.0078
# Epoch [499/500], Loss: 0.0028
# Epoch [499/500], Loss: 0.0257
# Epoch [499/500], Loss: 0.0063
# Epoch [499/500], Loss: 0.0019
# Epoch [499/500], Loss: 0.0003
# Epoch [499/500], Loss: 0.0067
# Epoch [499/500], Loss: 0.0012
# Epoch [499/500], Loss: 0.0030
# Epoch [499/500], Loss: 0.0394
# Epoch [499/500], Loss: 0.0297
# Epoch [499/500], Loss: 0.0013
# Epoch [499/500], Loss: 0.0039
# Epoch [499/500], Loss: 0.0016
# Epoch [499/500], Loss: 0.0033
# Epoch [499/500], Loss: 0.3074
# Epoch [499/500], Loss: 0.0099
# Epoch [499/500], Loss: 0.0117
# Epoch [499/500], Loss: 0.0043
# Epoch [499/500], Loss: 0.1041
# Epoch [499/500], Loss: 0.0063
# Epoch [499/500], Loss: 0.0020
# Epoch [499/500], Loss: 0.0106
# Epoch [499/500], Loss: 0.0048
# Epoch [500/500], Loss: 0.0310
# Epoch [500/500], Loss: 0.0198
# Epoch [500/500], Loss: 0.0219
# Epoch [500/500], Loss: 0.0077
# Epoch [500/500], Loss: 0.1010
# Epoch [500/500], Loss: 0.0172
# Epoch [500/500], Loss: 0.0105
# Epoch [500/500], Loss: 0.0585
# Epoch [500/500], Loss: 0.0039
# Epoch [500/500], Loss: 0.0070
# Epoch [500/500], Loss: 0.0028
# Epoch [500/500], Loss: 0.3047
# Epoch [500/500], Loss: 0.0037
# Epoch [500/500], Loss: 0.1276
# Epoch [500/500], Loss: 0.0198
# Epoch [500/500], Loss: 0.0147
# Epoch [500/500], Loss: 0.0203
# Epoch [500/500], Loss: 0.0073
# Epoch [500/500], Loss: 0.0091
# Epoch [500/500], Loss: 0.0034
# Epoch [500/500], Loss: 0.0315
# Epoch [500/500], Loss: 0.0057
# Epoch [500/500], Loss: 0.0084
# Epoch [500/500], Loss: 0.0066
# Epoch [500/500], Loss: 0.0031
# Epoch [500/500], Loss: 0.0013
# Epoch [500/500], Loss: 0.0044
# Epoch [500/500], Loss: 0.1798
# Epoch [500/500], Loss: 0.0051
# Epoch [500/500], Loss: 0.0118
# Epoch [500/500], Loss: 0.0060
# Epoch [500/500], Loss: 0.0011
# Epoch [500/500], Loss: 0.0042

# %%
# Evaluation
model.eval()
with torch.no_grad():
    all_predictions = []
    all_targets = []
    for images, targets in test_loader:
        
        # Move data to device
        images = images.to(device)
        targets = targets.unsqueeze(1).to(device)

        # Forward pass
        outputs = model(images)
        predictions = torch.round(outputs)

        # Collect predictions and targets
        all_predictions.extend(predictions.cpu().numpy().flatten().tolist())
        all_targets.extend(targets.cpu().numpy().flatten().tolist())

    # Calculate metrics
    correct = sum(all_predictions[i] == all_targets[i] for i in range(len(all_predictions)))
    accuracy = correct / len(all_predictions)
    tp = sum(all_predictions[i] == 1 and all_targets[i] == 1 for i in range(len(all_predictions)))
    tn = sum(all_predictions[i] == 0 and all_targets[i] == 0 for i in range(len(all_predictions)))
    fp = sum(all_predictions[i] == 1 and all_targets[i] == 0 for i in range(len(all_predictions)))
    fn = sum(all_predictions[i] == 0 and all_targets[i] == 1 for i in range(len(all_predictions)))
    sensitivity = tp / (tp + fn)
    specificity = tn / (tn + fp)
    auc = roc_auc_score(all_targets, all_predictions)
    p_value = ttest_ind(all_predictions, all_targets).pvalue

# %%
# Print the evaluation results
print("Accuracy:", accuracy)
print("Sensitivity:", sensitivity)
print("Specificity:", specificity)
print("AUC:", auc)
print("p-value:", p_value)
# Out:
# Accuracy: 0.9348066298342541
# Sensitivity: 1.0
# Specificity: 0.8778467908902692
# AUC: 0.9389233954451346
# p-value: 0.0055263590574013205
